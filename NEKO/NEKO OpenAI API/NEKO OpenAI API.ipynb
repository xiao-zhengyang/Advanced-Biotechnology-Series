# %% [markdown]
# **Step 1: Literature search and text collection**

# %%
# Search PubMed and get article abstracts

# pip install biopython pandas openpyxl

from Bio import Entrez
import pandas as pd

# Define your email to use with NCBI Entrez
Entrez.email = "your@email.com"

def search_pubmed(keyword):
    
    # Adjust the search term to focus on abstracts
    search_term = f"{keyword}[Abstract]"
    handle = Entrez.esearch(db="pubmed", term=search_term, retmax=500)
    record = Entrez.read(handle)
    handle.close()
    # Get the list of Ids returned by the search
    id_list = record["IdList"]
    return id_list

def fetch_details(id_list):
    ids = ','.join(id_list)
    handle = Entrez.efetch(db="pubmed", id=ids, retmode="xml")
    records = Entrez.read(handle)
    handle.close()

    # Create a list to hold our article details
    articles = []

    for pubmed_article in records['PubmedArticle']:
        article = {}
        article_data = pubmed_article['MedlineCitation']['Article']
        article['Title'] = article_data.get('ArticleTitle')
        
        # Directly output the abstract
        abstract_text = article_data.get('Abstract', {}).get('AbstractText', [])
        if isinstance(abstract_text, list):
            abstract_text = ' '.join(abstract_text)
        article['Abstract'] = abstract_text

        article['Journal'] = article_data.get('Journal', {}).get('Title')

        articles.append(article)

    return articles



# Example usage
keyword = "yarrowia carotene"
id_list = search_pubmed(keyword)
articles = fetch_details(id_list)

# Convert our list of articles to a DataFrame
df = pd.DataFrame(articles)

# Saving the DataFrame to an Excel file
excel_filename = keyword+"_pubmed_search_results.xlsx"
df.to_excel(excel_filename, index=False)

print(f"Saved search results to {excel_filename}")
# Out:
# Saved search results to yarrowia carotene_pubmed_search_results.xlsx

# %% [markdown]
# **Step 2: Entity and relationship extraction with LLM**

# %%
import pandas as pd
import os
from openai import OpenAI  # Updated import syntax

# Initialize OpenAI client (put your key here)
client = OpenAI(api_key="YOUR-API-KEY")  # New client initialization

def ask_questions(abstract, questions, system_prompts):
    responses = []
    for question, system_prompt in zip(questions, system_prompts):
        prompt_text = question + " " + str(abstract)
        messages = [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": prompt_text}
        ]
        try:
            # Updated API call syntax
            response = client.chat.completions.create(
                model="gpt-4o-mini",  # Use the latest model you have access to
                messages=messages,
                max_tokens=5000,
                temperature=0
            )
            answer = response.choices[0].message.content
            responses.append(answer.strip())
        except Exception as e:
            print(f"Error getting response: {e}")
            responses.append("")
    return responses

# ---------------------------------------------------
# Example usage reading from Excel and saving results
# ---------------------------------------------------
# Read the Excel file
file_path = excel_filename  # Replace with your file path
df = pd.read_excel(file_path)

questions = [" "]
system_prompts = [
    "You are a specialized analyzer for scientific paper abstracts with a focus on identifying causal relationships between key entities in biological studies. Your primary task is to extract and identify all causal relationships present in an abstract between the following entities: Performance, Species, Genes, Methods of genetic engineering (such as knockout or expression), Enzymes, Proteins, and Bioprocess conditions (e.g., growth conditions). For each abstract provided, identify every causal relationship between these entities. You must consider all combinations, even indirect relationships, and output a long, detailed answer that includes every possible valid combination pair. Your output should strictly follow this format: (Entity A, Entity B), (Entity C, Entity D), ... with no additional text. Important Instructions: Comprehensiveness: Include all valid combinations of causal relationships found in the abstract; Detail: Ensure the output is long and detailed, listing every relationship pair even if some relationships may be indirectly connected; Format: Output only the pairs in the exact format described above with no additional explanations or commentary. Examples: Example 1: Abstract: The knockout of gene X significantly improved performance in species Y. Output: (gene X, performance), (gene X, species Y), (species Y, performance). Example 2: Abstract: Expression of enzyme Z in species W leads to increased protein levels under specific growth conditions. Output: (enzyme Z, protein levels), (enzyme Z, species W), (enzyme Z, growth conditions), (protein levels, species W), (protein levels, growth conditions), (species W, growth conditions). Example 3: Abstract: The study shows that a change in bioprocess conditions influences the expression of gene A, which in turn affects the performance of species B. Output: (bioprocess conditions, gene A), (bioprocess conditions, performance), (bioprocess conditions, species B), (gene A, performance), (gene A, species B), (performance, species B).",
]
# Process each abstract and store the response
total_rows = len(df)
for i, row in df.iterrows():
    os.system('cls' if os.name == 'nt' else 'clear')
    response = ask_questions(row['Abstract'], [questions[0]], [system_prompts[0]])[0]
    df.at[i, 'Extracted entities'] = response
    
    print(f"Response for Row {i+1}:")
    print(f"Answer to Question 2: {response}")
    progress = ((i + 1) / total_rows) * 100
    print(f"Progress: {progress:.2f}% completed")

# Save the updated DataFrame
output_file_path = f'updated(GPT-4o)_{keyword}_causal.xlsx'  # New filename
df.to_excel(output_file_path, index=False)
# Out:
# Response for Row 1:
# Answer to Question 2: (Yarrowia lipolytica, growth), (Yarrowia lipolytica, lipid utilization), (Yarrowia lipolytica, efficiency), (Yarrowia lipolytica, Po1f strain), (Po1f strain, growth), (Po1f strain, lipid utilization), (Po1f strain, efficiency), (engineered strain, growth rate), (engineered strain, lipid content), (engineered strain, lipid uptake), (engineered strain, lipid accumulation), (engineered strain, lipid metabolism), (engineered strain, Yarrowia lipolytica), (original strain, growth rate), (original strain, lipid content), (original strain, lipid uptake), (original strain, lipid accumulation), (original strain, lipid metabolism), (original strain, Yarrowia lipolytica), (β-Carotene, production of lipophilic natural compounds), (engineered strain, β-Carotene), (engineered strain, efficiency), (growth rate, efficiency), (lipid content, efficiency), (lipid uptake, efficiency), (lipid accumulation, efficiency), (lipid metabolism, efficiency), (growth, lipid utilization), (growth, efficiency), (lipid utilization, efficiency).
# Progress: 1.10% completed
# Response for Row 2:
# Answer to Question 2: (ABC transporters, squalene secretion), (carrier protein-mediated metabolite trafficking system, squalene secretion), (squalene biosynthesis pathway, squalene production), (SNQ2, squalene secretion), (OSH3, squalene secretion), (SNQ2, OSH3), (signal peptide optimization, squalene secretion), (signal peptide optimization, carrier protein-mediated metabolite trafficking system), (squalene secretion, Yarrowia lipolytica), (squalene production, Yarrowia lipolytica), (β-carotene, extracellular export), (fed-batch cultivation, squalene secretion), (engineered strain, squalene secretion), (engineered strain, Yarrowia lipolytica), (squalene secretion, total production), (squalene secretion, 144.67 mg/L), (squalene secretion, 3.43 g/L), (squalene secretion, 17-fold improvement), (squalene secretion, highest secretion level), (Yarrowia lipolytica, terpenoid production).
# Progress: 2.20% completed
# Response for Row 3:
# Answer to Question 2: (substrate choice, biomass yield), (substrate choice, lipid content), (substrate choice, β-carotene levels), (substrate choice, Yarrowia lipolytica), (biomass yield, Yarrowia lipolytica), (lipid content, Yarrowia lipolytica), (β-carotene levels, Yarrowia lipolytica), (glycerol, biomass yield), (glycerol, lipid content), (glycerol, β-carotene levels), (glucose, lipid content), (glucose, β-carotene levels), (acetic acid, lipid content), (acetic acid, lipid concentration), (glucose, biomass yield), (glucose, biomass concentration), (glycerol, biomass concentration), (acetic acid, biomass concentration), (bioprocess conditions, substrate choice), (bioprocess conditions, Yarrowia lipolytica), (bioprocess conditions, biomass yield), (bioprocess conditions, lipid content), (bioprocess conditions, β-carotene levels).
# Progress: 3.30% completed
# Response for Row 4:
# Answer to Question 2: (β-carotene, performance), (β-carotene, Yarrowia lipolytica), (Yarrowia lipolytica, performance), (pathway genes, β-carotene), (pathway genes, Yarrowia lipolytica), (lycopene inhibition, β-carotene), (lycopene inhibition, Yarrowia lipolytica), (carbon pathway, β-carotene), (carbon pathway, Yarrowia lipolytica), (NADPH regeneration, β-carotene), (NADPH regeneration, Yarrowia lipolytica), (ATP expenditure, β-carotene), (ATP expenditure, Yarrowia lipolytica), (pentose phosphate pathway, β-carotene), (pentose phosphate pathway, Yarrowia lipolytica), (NADP<sup>+</sup>-dependent glyceraldehyde-3-phosphate dehydrogenase, β-carotene), (NADP<sup>+</sup>-dependent glyceraldehyde-3-phosphate dehydrogenase, Yarrowia lipolytica), (phosphoketolase-phosphotransacetylase pathway, β-carotene), (phosphoketolase-phosphotransacetylase pathway, Yarrowia lipolytica), (lipid biosynthesis pathway, β-carotene), (lipid biosynthesis pathway, Yarrowia lipolytica), (iterative overexpression, β-carotene), (iterative overexpression, Yarrowia lipolytica), (central carbon pathway engineering, β-carotene), (central carbon pathway engineering, Yarrowia lipolytica), (lipid pathway flux adjustment, β-carotene), (lipid pathway flux adjustment, Yarrowia lipolytica), (β-carotene production chassis, β-carotene), (β-carotene production chassis, Yarrowia lipolytica), (β-carotene production chassis, performance).
# Progress: 4.40% completed
# Response for Row 5:
# Answer to Question 2: (crocetin, diseases), (crocetin, nutritional applications), (crocetin, saffron), (saffron, crocetin), (metabolic engineering, crocetin), (synthetic biology, crocetin), (Yarrowia lipolytica, crocetin), (Yarrowia lipolytica, β-carotene), (β-carotene, crocetin), (hybrid promoters, Yarrowia lipolytica), (copy number adjustment, Yarrowia lipolytica), (temperature, crocetin biosynthesis), (temperature, Yarrowia lipolytica), (temperature, β-carotene), (temperature, enzyme activity), (two-step temperature-shift fermentation strategy, yeast growth), (two-step temperature-shift fermentation strategy, enzyme activity), (fermentation media, crocetin), (fermentation media, Yarrowia lipolytica), (fermentation media, β-carotene), (fermentation media, temperature), (Yarrowia lipolytica, zeaxanthin), (zeaxanthin, Yarrowia lipolytica), (metabolic engineering, zeaxanthin), (fermentation optimization, crocetin), (fermentation optimization, zeaxanthin), (fermentation optimization, Yarrowia lipolytica), (crocetin, titer), (zeaxanthin, titer), (crocetin, sustainable production), (zeaxanthin, sustainable production).
# Progress: 5.49% completed
# Response for Row 6:
# Answer to Question 2: (species Yarrowia lipolytica, performance), (species Yarrowia lipolytica, β-carotene), (species Yarrowia lipolytica, biomass), (species Yarrowia lipolytica, citric acid), (wild-type strain, performance), (wild-type strain, biomass), (wild-type strain, citric acid), (upcycler strain, performance), (upcycler strain, citric acid), (upcycler strain, β-carotene), (bioprocess conditions, performance), (bioprocess conditions, β-carotene), (bioprocess conditions, biomass), (bioprocess conditions, citric acid), (bioprocess conditions, species Yarrowia lipolytica), (bioprocess conditions, wild-type strain), (bioprocess conditions, upcycler strain), (citric acid, performance), (citric acid, β-carotene), (citric acid, biomass), (biomass, performance), (biomass, β-carotene).
# Progress: 6.59% completed
# Response for Row 7:
# Answer to Question 2: (phytoene, performance), (phytoene, Yarrowia lipolytica), (Yarrowia lipolytica, performance), (heterologous phytoene synthase gene, phytoene), (heterologous phytoene synthase gene, Yarrowia lipolytica), (key genes, phytoene), (key genes, Yarrowia lipolytica), (metabolic engineering approaches, phytoene), (metabolic engineering approaches, Yarrowia lipolytica), (glyoxylate cycle, phytoene), (glyoxylate cycle, Yarrowia lipolytica), (acetyl-CoA, phytoene), (acetyl-CoA, Yarrowia lipolytica), (peroxisomes, phytoene), (peroxisomes, Yarrowia lipolytica), (flask-scale fed-batch culture, phytoene), (flask-scale fed-batch culture, Yarrowia lipolytica), (phytoene production, performance), (phytoene production, Yarrowia lipolytica), (1.34 g/L titer, performance), (58.74 mg/gDCW yield, performance), (1.34 g/L titer, Yarrowia lipolytica), (58.74 mg/gDCW yield, Yarrowia lipolytica).
# Progress: 7.69% completed
# Response for Row 8:
# Answer to Question 2: (zeaxanthin, performance), (β-cryptoxanthin, performance), (Yarrowia lipolytica, zeaxanthin), (Yarrowia lipolytica, β-cryptoxanthin), (β-carotene, β-cryptoxanthin), (β-carotene, zeaxanthin), (β-carotene hydroxylase, zeaxanthin), (β-carotene hydroxylase, β-cryptoxanthin), (CcBCH, β-cryptoxanthin), (CcBCH, Yarrowia lipolytica), (CcBCH, performance), (environmental implications, microbial fermentation), (health implications, microbial fermentation), (bioprocess conditions, zeaxanthin), (bioprocess conditions, β-cryptoxanthin), (bioprocess conditions, Yarrowia lipolytica), (bioprocess conditions, performance), (enzymes, β-cryptoxanthin), (enzymes, zeaxanthin), (enzymes, Yarrowia lipolytica), (enzymes, performance), (targeting, zeaxanthin), (targeting, β-cryptoxanthin), (targeting, β-carotene hydroxylase), (targeting, performance), (multienzyme complexes, zeaxanthin), (multienzyme complexes, performance), (short peptide tags, zeaxanthin), (short peptide tags, performance), (zeaxanthin, conversion rate), (β-cryptoxanthin, conversion rate), (Yarrowia lipolytica, conversion rate), (biotechnological production, β-cryptoxanthin), (biotechnological production, zeaxanthin), (biotechnological production, performance), (β-cryptoxanthin, extraction yields), (β-carotene, extraction yields), (β-cryptoxanthin, health functions), (β-carotene, health functions), (environmental implications, health implications).
# Progress: 8.79% completed
# Response for Row 9:
# Answer to Question 2: (β-ionone, Yarrowia lipolytica), (β-ionone, acetyl-CoA), (β-ionone, CCD genes), (β-ionone, strain XK17), (β-ionone, strain rUinO-D14), (β-ionone, Osmanthus fragrans), (β-ionone, mevalonate pathway), (β-ionone, non-homologous end joining), (β-ionone, protein tagging strategy), (β-ionone, heterologous oxidoreductase pathway), (β-ionone, xylose), (β-ionone, lignocellulosic hydrolysate), (Yarrowia lipolytica, acetyl-CoA), (Yarrowia lipolytica, CCD genes), (Yarrowia lipolytica, strain XK17), (Yarrowia lipolytica, strain rUinO-D14), (Yarrowia lipolytica, Osmanthus fragrans), (Yarrowia lipolytica, mevalonate pathway), (Yarrowia lipolytica, non-homologous end joining), (Yarrowia lipolytica, protein tagging strategy), (Yarrowia lipolytica, heterologous oxidoreductase pathway), (Yarrowia lipolytica, xylose), (Yarrowia lipolytica, lignocellulosic hydrolysate), (acetyl-CoA, CCD genes), (acetyl-CoA, strain XK17), (acetyl-CoA, strain rUinO-D14), (acetyl-CoA, Osmanthus fragrans), (acetyl-CoA, mevalonate pathway), (acetyl-CoA, non-homologous end joining), (acetyl-CoA, protein tagging strategy), (acetyl-CoA, heterologous oxidoreductase pathway), (acetyl-CoA, xylose), (acetyl-CoA, lignocellulosic hydrolysate), (CCD genes, strain XK17), (CCD genes, strain rUinO-D14), (CCD genes, Osmanthus fragrans), (CCD genes, mevalonate pathway), (CCD genes, non-homologous end joining), (CCD genes, protein tagging strategy), (CCD genes, heterologous oxidoreductase pathway), (CCD genes, xylose), (CCD genes, lignocellulosic hydrolysate), (strain XK17, strain rUinO-D14), (strain XK17, Osmanthus fragrans), (strain XK17, mevalonate pathway), (strain XK17, non-homologous end joining), (strain XK17, protein tagging strategy), (strain XK17, heterologous oxidoreductase pathway), (strain XK17, xylose), (strain XK17, lignocellulosic hydrolysate), (strain rUinO-D14, Osmanthus fragrans), (strain rUinO-D14, mevalonate pathway), (strain rUinO-D14, non-homologous end joining), (strain rUinO-D14, protein tagging strategy), (strain rUinO-D14, heterologous oxidoreductase pathway), (strain rUinO-D14, xylose), (strain rUinO-D14, lignocellulosic hydrolysate), (Osmanthus fragrans, mevalonate pathway), (Osmanthus fragrans, non-homologous end joining), (Osmanthus fragrans, protein tagging strategy), (Osmanthus fragrans, heterologous oxidoreductase pathway), (Osmanthus fragrans, xylose), (Osmanthus fragrans, lignocellulosic hydrolysate), (mevalonate pathway, non-homologous end joining), (mevalonate pathway, protein tagging strategy), (mevalonate pathway, heterologous oxidoreductase pathway), (mevalonate pathway, xylose), (mevalonate pathway, lignocellulosic hydrolysate), (non-homologous end joining, protein tagging strategy), (non-homologous end joining, heterologous oxidoreductase pathway), (non-homologous end joining, xylose), (non-homologous end joining, lignocellulosic hydrolysate), (protein tagging strategy, heterologous oxidoreductase pathway), (protein tagging strategy, xylose), (protein tagging strategy, lignocellulosic hydrolysate), (heterologous oxidoreductase pathway, xylose), (heterologous oxidoreductase pathway, lignocellulosic hydrolysate), (xylose, lignocellulosic hydrolysate).
# Progress: 9.89% completed
# Response for Row 10:
# Answer to Question 2: (yeast, microbial cell factories), (yeast, synthetic biology tools), (synthetic biology tools, industrial chassis strains), (microbial host, metabolic engineering applications), (microbial host, strain diversity), (strain diversity, specific traits), (strain diversity, phenotypes), (synthetic biology tools, non-type strains), (non-type strains, reshaped), (Yarrowia lipolytica, applications), (Yarrowia lipolytica, fuels), (Yarrowia lipolytica, chemicals), (Yarrowia lipolytica, food), (Yarrowia, industrial potential), (synthetic biology tools, Yarrowia), (synthetic biology tools, other yeasts), (Golden Gate Y. lipolytica tool kit, fluorescent proteins), (Golden Gate Y. lipolytica tool kit, carotenoid pathway), (Golden Gate Y. lipolytica tool kit, Yarrowia), (fluorescent proteins, Yarrowia), (carotenoid pathway, Yarrowia), (Yarrowia, uncharacterized strains), (uncharacterized strains, potential applications), (uncharacterized strains, biotechnology).
# Progress: 10.99% completed
# Response for Row 11:
# Answer to Question 2: (gene copy number, chromosomal integration), (gene copy number, microbial cell factories), (gene copy number, genetic systems), (gene copy number, homologous recombination), (gene copy number, repetitive DNA sequences), (gene copy number, optimal copy number), (gene copy number, pathway), (chromosomal integration, microbial cell factories), (chromosomal integration, genetic systems), (chromosomal integration, homologous recombination), (chromosomal integration, repetitive DNA sequences), (chromosomal integration, optimal copy number), (chromosomal integration, pathway), (microbial cell factories, genetic systems), (microbial cell factories, homologous recombination), (microbial cell factories, repetitive DNA sequences), (microbial cell factories, optimal copy number), (microbial cell factories, pathway), (genetic systems, homologous recombination), (genetic systems, repetitive DNA sequences), (genetic systems, optimal copy number), (genetic systems, pathway), (homologous recombination, repetitive DNA sequences), (homologous recombination, optimal copy number), (homologous recombination, pathway), (repetitive DNA sequences, optimal copy number), (repetitive DNA sequences, pathway), (optimal copy number, pathway), (machine learning method, optimal copy number), (engineered Yarrowia lipolytica strain, eicosapentaenoic acid biosynthesis), (engineered Yarrowia lipolytica strain, titer), (engineered Yarrowia lipolytica strain, bioreactor), (titer, bioreactor), (lycopene production, Escherichia coli), (engineered strains, Yarrowia lipolytica), (engineered strains, Escherichia coli), (engineered strains, Saccharomyces cerevisiae), (nonrepetitive CDSs, genetic stability), (Yarrowia lipolytica, eicosapentaenoic acid biosynthesis), (Yarrowia lipolytica, titer), (Yarrowia lipolytica, bioreactor), (Escherichia coli, lycopene production), (Escherichia coli, genetic stability), (Saccharomyces cerevisiae, genetic stability).
# Progress: 12.09% completed
# Response for Row 12:
# Answer to Question 2: (haematococcus pluvialis, astaxanthin), (xanthophyllomyces dendrorhous, astaxanthin), (escherichia coli, astaxanthin), (saccharomyces cerevisiae, astaxanthin), (yarrowia lipolytica, astaxanthin), (genes, astaxanthin), (genes, escherichia coli), (genes, saccharomyces cerevisiae), (genes, yarrowia lipolytica), (astaxanthin, performance), (extraction methods, astaxanthin), (superfluid extraction, astaxanthin), (ionic liquid extraction, astaxanthin), (microwave-assisted extraction, astaxanthin), (extraction methods, efficiency), (superfluid extraction, efficiency), (ionic liquid extraction, efficiency), (microwave-assisted extraction, efficiency), (escherichia coli, efficiency), (saccharomyces cerevisiae, efficiency), (yarrowia lipolytica, efficiency), (astaxanthin, microbial hosts), (astaxanthin, strategies), (strategies, efficiency), (strategies, astaxanthin).
# Progress: 13.19% completed
# Response for Row 13:
# Answer to Question 2: (growth conditions, astaxanthin production), (Yarrowia lipolytica, astaxanthin production), (Yarrowia lipolytica, growth conditions), (Yarrowia lipolytica M2, astaxanthin production), (Yarrowia lipolytica M2, growth conditions), (Yarrowia lipolytica M1, astaxanthin production), (Yarrowia lipolytica M1, growth conditions), (astaxanthin production, cell biomass), (cell biomass, astaxanthin production), (RNA-seq analysis, gene expression), (gene expression, astaxanthin production), (gene expression, Yarrowia lipolytica M2), (gene expression, Yarrowia lipolytica M1), (differentially expressed genes, astaxanthin production), (differentially expressed genes, Yarrowia lipolytica M2), (differentially expressed genes, Yarrowia lipolytica M1), (carbon flux, astaxanthin production), (carbon flux, lipid metabolism), (carbon flux, acetyl-CoA), (carbon flux, mevalonate), (carbon flux, central carbon metabolism), (lipid metabolism, astaxanthin production), (lipid metabolism, acetyl-CoA), (lipid metabolism, mevalonate), (acetyl-CoA, astaxanthin production), (mevalonate, astaxanthin production), (upregulation of pathways, astaxanthin production), (upregulation of pathways, cofactors), (upregulation of pathways, carotenoid hydroxylase), (upregulation of pathways, cell membrane stress), (carotenoid hydroxylase, astaxanthin production), (cofactors, astaxanthin production), (cell membrane stress, astaxanthin production), (cell growth, astaxanthin production), (cell growth, Yarrowia lipolytica), (astaxanthin production, Yarrowia lipolytica).
# Progress: 14.29% completed
# Response for Row 14:
# Answer to Question 2: (retinol, human visual functions), (retinol, human immune functions), (microbial fermentation, retinol), (microbial fermentation, titer), (titer, retinal), (titer, retinol), (titer, retinoic acid), (retinol, purification), (β-carotene, retinol), (β-carotene, metabolic flux), (β-carotene 15,15'-dioxygenase, retinol), (β-carotene 15,15'-dioxygenase, expression level), (Tween 80, retinol), (butylated hydroxytoluene, retinol), (butylated hydroxytoluene, retinol oxidation), (retinol, production level), (enzymes, retinal), (enzymes, retinol), (extracellular retinol, retinoids), (extracellular retinol, total retinol production), (intracellular retinol, total retinol production), (fed-batch fermentation, retinol), (5 L bioreactor, retinol), (5 L bioreactor, total retinol production), (5 L bioreactor, extracellular retinol), (5 L bioreactor, intracellular retinol).
# Progress: 15.38% completed
# Response for Row 15:
# Answer to Question 2: (ABA, plant growth), (ABA, adverse growth environment), (heterologous biosynthesis, ABA yield), (Botrytis cinerea genes, ABA biosynthesis), (bcaba1, ABA production), (bcaba2, ABA production), (bcaba3, ABA production), (bcaba4, ABA production), (bccpr1, ABA production), (Yarrowia lipolytica, ABA production), (copy number of IDI, ABA yield), (copy number of ERG12S, ABA yield), (copy number of ERG20Y, ABA yield), (copy number of bcaba3, ABA yield), (copy number of bcaba1, ABA yield), (HMG-CoA reductase, ABA yield), (HMG-CoA synthase, ABA yield), (acetyl-CoA, mevalonate), (mevalonate, ABA yield), (fed-batch fermentation process, ABA yield), (dodecane, ABA yield), (ABA yield, heterologous production), (ABA yield, metabolic engineering).
# Progress: 16.48% completed
# Response for Row 16:
# Answer to Question 2: (lutein, microbial synthesis), (lutein, feed), (lutein, cosmetics), (lutein, food), (lutein, drugs), (precursor supply, microbial synthesis), (catalytic efficiency, microbial synthesis), (key pathway enzymes, microbial synthesis), (MVA pathway, α-carotene), (α-carotene synthase OluLCY, α-carotene), (α-carotene, α-carotene titer), (α-carotene, Yarrowia lipolytica), (hydroxylase activity, lutein), (truncated N-terminal transport peptide, hydroxylase activity), (hydroxylases, subcellular organelles), (final strain L9, lutein), (final strain L9, hydroxylase activity), (lutein, bioreactor), (2,6-ditert-butyl-4-methylphenol, lutein), (bioreactor, lutein), (bioreactor, α-carotene), (Yarrowia lipolytica, lutein), (Yarrowia lipolytica, α-carotene), (Yarrowia lipolytica, hydroxylase activity), (Yarrowia lipolytica, final strain L9), (Yarrowia lipolytica, bioprocess conditions).
# Progress: 17.58% completed
# Response for Row 17:
# Answer to Question 2: (yarrowia lipolytica, β-carotene), (yarrowia lipolytica, lipids), (syngas-derived acetic acid, β-carotene), (syngas-derived acetic acid, lipids), (acetic acid, lipid profiles), (acetic acid, β-carotene production), (acetic acid concentration, lipid profiles), (acetic acid concentration, β-carotene production), (acetic acid consumption, β-carotene production), (acetic acid consumption, lipids), (clostridium aceticum, acetic acid), (syngas, acetic acid), (syngas, yarrowia lipolytica), (syngas, clostridium aceticum), (bioprocesses, β-carotene), (bioprocesses, lipids), (bioprocesses, syngas-derived acetic acid), (bioprocesses, yarrowia lipolytica), (bioprocesses, clostridium aceticum).
# Progress: 18.68% completed
# Response for Row 18:
# Answer to Question 2: (engineered Yarrowia lipolytica strain, β-carotene), (engineered Yarrowia lipolytica strain, lipids), (engineered Yarrowia lipolytica strain, acetic acid), (engineered Yarrowia lipolytica strain, specific nutrient conditions), (engineered Yarrowia lipolytica strain, pH effects), (engineered Yarrowia lipolytica strain, bioreactors), (acetic acid, β-carotene), (acetic acid, lipids), (acetic acid, specific nutrient conditions), (acetic acid, pH effects), (acetic acid, bioreactors), (specific nutrient conditions, β-carotene), (specific nutrient conditions, lipids), (specific nutrient conditions, pH effects), (specific nutrient conditions, bioreactors), (pH effects, β-carotene), (pH effects, lipids), (pH effects, bioreactors), (bioreactors, β-carotene), (bioreactors, lipids), (lipid content, β-carotene concentration), (lipid content, pH effects), (lipid content, specific nutrient conditions), (lipid content, engineered Yarrowia lipolytica strain), (β-carotene concentration, pH effects), (β-carotene concentration, specific nutrient conditions), (β-carotene concentration, engineered Yarrowia lipolytica strain), (lipids, engineered Yarrowia lipolytica strain), (lipids, pH effects), (lipids, specific nutrient conditions).
# Progress: 19.78% completed
# Response for Row 19:
# Answer to Question 2: (zeaxanthin, antioxidant properties), (zeaxanthin, anti-inflammatory properties), (zeaxanthin, anticancer properties), (zeaxanthin, neuroprotective properties), (Yarrowia lipolytica, zeaxanthin), (Yarrowia lipolytica, β-carotene), (Yarrowia lipolytica PO1h, β-carotene), (Yarrowia lipolytica PO1h, zeaxanthin), (Yarrowia lipolytica PEX17-HA, β-carotene), (Yarrowia lipolytica PEX17-HA, zeaxanthin), (β-carotene, concentration), (β-carotene, mevalonate), (mvaE, β-carotene), (mvaS, β-carotene), (crtZ, zeaxanthin), (RFNR1, zeaxanthin), (CrtZ, zeaxanthin), (β-carotene, yield), (mevalonate, β-carotene), (β-carotene, YPD shake flask), (zeaxanthin, YPD shake flask), (Yarrowia lipolytica, growth conditions), (Yarrowia lipolytica, engineered strains), (engineered strains, β-carotene), (engineered strains, zeaxanthin), (wild and mutant enzyme comparison, β-carotene), (successive modular assembly, β-carotene), (key nodes on the carotenoid pathway, β-carotene), (key nodes on the carotenoid pathway, zeaxanthin).
# Progress: 20.88% completed
# Response for Row 20:
# Answer to Question 2: (crispr-cas9 technology, Yarrowia lipolytica), (crispr-iCas9, Yarrowia lipolytica), (crispr-iCas9, carotene synthetic key genes), (crispr-iCas9, target product yield), (crispr-iCas9, genetic modification), (crispr-iCas9, knockout of nonsense suppressors), (crispr-iCas9, knockout efficiency), (crispr-iCas9, gene integration), (crispr-iCas9, β-carotene content), (crispr-iCas9, zeaxanthin content), (Yarrowia lipolytica, carotene synthetic key genes), (Yarrowia lipolytica, target product yield), (Yarrowia lipolytica, genetic modification), (Yarrowia lipolytica, knockout of nonsense suppressors), (Yarrowia lipolytica, knockout efficiency), (Yarrowia lipolytica, gene integration), (Yarrowia lipolytica, β-carotene content), (Yarrowia lipolytica, zeaxanthin content), (carotene synthetic key genes, target product yield), (carotene synthetic key genes, β-carotene content), (carotene synthetic key genes, zeaxanthin content), (target product yield, β-carotene content), (target product yield, zeaxanthin content), (knockout of nonsense suppressors, knockout efficiency), (knockout efficiency, gene integration), (gene integration, β-carotene content), (gene integration, zeaxanthin content).
# Progress: 21.98% completed
# Response for Row 21:
# Answer to Question 2: (yeast cells, performance), (yeast strains, performance), (yeast strains, erythritol), (Mhy1, yeast-like morphology), (Cla4, yeast-like morphology), (Mhy1, Cla4), (CarRA, β-carotene), (CarB, β-carotene), (Blakeslea trispora, β-carotene), (GGS1, β-carotene yield), (tHMG1, β-carotene yield), (YTH1, fermentation delays), (YTH3, fermentation delays), (β-carotene, fermentation time), (β-carotene yield, fermentation time), (Y. lipolytica, erythritol), (Y. lipolytica, β-carotene), (Y. lipolytica, yeast-like morphology), (bioreactor, erythritol production), (bioreactor, β-carotene yield), (bioprocess conditions, erythritol production), (bioprocess conditions, β-carotene yield), (bioprocess conditions, fermentation delays), (bioprocess conditions, yeast-like morphology), (erythritol, β-carotene), (erythritol, performance), (β-carotene, performance).
# Progress: 23.08% completed
# Response for Row 22:
# Answer to Question 2: (abscisic acid, growth), (abscisic acid, metabolism), (abscisic acid, drought resistance), (abscisic acid, salt tolerance), (abscisic acid, fruit browning), (abscisic acid, incidence rate of malaria), (abscisic acid, insulin secretion), (abscisic acid, agriculture), (abscisic acid, medicine), (abscisic acid, microorganisms), (abscisic acid, Botrytis cinerea), (abscisic acid, Cercospora rosea), (abscisic acid, Saccharomyces cerevisiae), (abscisic acid, Yarrowia lipolytica), (abscisic acid, Escherichia coli), (Botrytis cinerea, abscisic acid), (Cercospora rosea, abscisic acid), (Saccharomyces cerevisiae, abscisic acid), (Yarrowia lipolytica, abscisic acid), (Escherichia coli, abscisic acid), (microorganisms, abscisic acid), (heterologous synthesis, abscisic acid), (chassis cells, abscisic acid), (key enzymes, abscisic acid), (cofactors, abscisic acid), (precursor supply, abscisic acid), (abscisic acid efflux, abscisic acid), (chassis cells, key enzymes), (chassis cells, cofactors), (chassis cells, precursor supply), (chassis cells, abscisic acid efflux), (key enzymes, cofactors), (key enzymes, precursor supply), (key enzymes, abscisic acid efflux), (cofactors, precursor supply), (cofactors, abscisic acid efflux), (precursor supply, abscisic acid efflux).
# Progress: 24.18% completed
# Response for Row 23:
# Answer to Question 2: (auxin-inducible degron technology, protein knockdown), (auxin-inducible degron technology, Yarrowia lipolytica), (plant auxin, protein knockdown), (plant auxin, Yarrowia lipolytica), (degron-tagged proteins, protein knockdown), (degron-tagged proteins, Yarrowia lipolytica), (mini-IAA7, protein knockdown), (mini-IAA7, Yarrowia lipolytica), (Oryza sativa TIR1, protein knockdown), (Oryza sativa TIR1, Yarrowia lipolytica), (copper-inducible MT2 promoter, protein knockdown), (copper-inducible MT2 promoter, Yarrowia lipolytica), (degron-tagged superfolder GFP, protein knockdown), (degron-tagged superfolder GFP, Yarrowia lipolytica), (copper, protein knockdown), (copper, Yarrowia lipolytica), (synthetic auxin 1-Naphthaleneacetic acid, protein knockdown), (synthetic auxin 1-Naphthaleneacetic acid, Yarrowia lipolytica), (OsTIR1 F74A variant, protein knockdown), (OsTIR1 F74A variant, Yarrowia lipolytica), (5-Ad-IAA, protein knockdown), (5-Ad-IAA, Yarrowia lipolytica), (degron-tagged GFP, leaky degradation), (leaky degradation, NAA), (degron-tagged GFP, proteolytic cleavage), (proteolytic cleavage, mIAA7 degron), (mIAA7 degron, GFP sub-population), (β-carotene ketolase, protein knockdown), (β-carotene ketolase, Yarrowia lipolytica), (β-carotene, canthaxanthin), (β-carotene, β-carotene producing Yarrowia lipolytica strain), (canthaxanthin production, protein knockdown), (copper, canthaxanthin production), (5-Ad-IAA, canthaxanthin production), (copper, Yarrowia lipolytica), (5-Ad-IAA, Yarrowia lipolytica), (copper and 5-Ad-IAA, canthaxanthin production), (copper and 5-Ad-IAA, Yarrowia lipolytica), (mIAA7/OsTIR1 F74A system, protein knockdown), (mIAA7/OsTIR1 F74A system, Yarrowia lipolytica), (AID system, Yarrowia lipolytica), (AID system, protein knockdown).
# Progress: 25.27% completed
# Response for Row 24:
# Answer to Question 2: (β-carotene, Yarrowia lipolytica), (β-carotene, carotenogenesis genes), (β-carotene, mevalonate pathway), (β-carotene, fatty acid synthesis pathway), (β-carotene, tHMGR), (β-carotene, β-carotene synthesis related genes), (Yarrowia lipolytica, carotenogenesis genes), (Yarrowia lipolytica, mevalonate pathway), (Yarrowia lipolytica, fatty acid synthesis pathway), (Yarrowia lipolytica, tHMGR), (Yarrowia lipolytica, β-carotene synthesis related genes), (carotenogenesis genes, β-carotene production), (mevalonate pathway, β-carotene production), (fatty acid synthesis pathway, β-carotene production), (tHMGR, β-carotene production), (β-carotene synthesis related genes, β-carotene production), (engineered strain Yli-C, β-carotene titer), (engineered strain Yli-CAH, β-carotene titer), (engineered strain Yli-C2AH2, β-carotene titer), (β-carotene titer, fermentation conditions), (fermentation conditions, β-carotene production), (engineered Yarrowia lipolytica, β-carotene synthesis pathway), (engineered Yarrowia lipolytica, fermentation conditions).
# Progress: 26.37% completed
# Response for Row 25:
# Answer to Question 2: (bacteria, oils or fats), (yeast, oils or fats), (Yarrowia lipolytica, oils or fats), (Yarrowia lipolytica, biomanufacturing), (Yarrowia lipolytica, value-added products), (Yarrowia lipolytica, fatty acid transport), (Yarrowia lipolytica, fatty acid catabolism), (Yarrowia lipolytica, bioconversion), (Yarrowia lipolytica, redox balances), (Yarrowia lipolytica, energy yield), (Yarrowia lipolytica, cell morphology), (Yarrowia lipolytica, stress response), (Yarrowia lipolytica, bioreaction engineering), (oils or fats, biomanufacturing), (oils or fats, value-added products), (oils or fats, fatty acid transport), (oils or fats, fatty acid catabolism), (oils or fats, bioconversion), (oils or fats, redox balances), (oils or fats, energy yield), (oils or fats, cell morphology), (oils or fats, stress response), (oils or fats, bioreaction engineering), (biomanufacturing, value-added products), (biomanufacturing, fatty acid transport), (biomanufacturing, fatty acid catabolism), (biomanufacturing, bioconversion), (biomanufacturing, redox balances), (biomanufacturing, energy yield), (biomanufacturing, cell morphology), (biomanufacturing, stress response), (biomanufacturing, bioreaction engineering), (value-added products, fatty acid transport), (value-added products, fatty acid catabolism), (value-added products, bioconversion), (value-added products, redox balances), (value-added products, energy yield), (value-added products, cell morphology), (value-added products, stress response), (value-added products, bioreaction engineering), (fatty acid transport, fatty acid catabolism), (fatty acid transport, bioconversion), (fatty acid transport, redox balances), (fatty acid transport, energy yield), (fatty acid transport, cell morphology), (fatty acid transport, stress response), (fatty acid transport, bioreaction engineering), (fatty acid catabolism, bioconversion), (fatty acid catabolism, redox balances), (fatty acid catabolism, energy yield), (fatty acid catabolism, cell morphology), (fatty acid catabolism, stress response), (fatty acid catabolism, bioreaction engineering), (bioconversion, redox balances), (bioconversion, energy yield), (bioconversion, cell morphology), (bioconversion, stress response), (bioconversion, bioreaction engineering), (redox balances, energy yield), (redox balances, cell morphology), (redox balances, stress response), (redox balances, bioreaction engineering), (energy yield, cell morphology), (energy yield, stress response), (energy yield, bioreaction engineering), (cell morphology, stress response), (cell morphology, bioreaction engineering), (stress response, bioreaction engineering).
# Progress: 27.47% completed
# Response for Row 26:
# Answer to Question 2: (β-carotene, antioxidant properties), (β-carotene, anti-cardiovascular properties), (β-carotene, microbial cell factories), (microbial cell factories, β-carotene), (microbial cell factories, Saccharomyces cerevisiae), (microbial cell factories, Yarrowia lipolytica), (Saccharomyces cerevisiae, β-carotene), (Yarrowia lipolytica, β-carotene), (microbial cell factories, genetic manipulation tools), (microbial cell factories, mevalonate pathway), (microbial cell factories, large-scale fermentation), (genetic manipulation tools, β-carotene), (mevalonate pathway, β-carotene), (large-scale fermentation, β-carotene), (protein engineering, β-carotene), (promoters engineering, β-carotene), (morphological engineering, β-carotene), (β-carotene, future engineering approaches).
# Progress: 28.57% completed
# Response for Row 27:
# Answer to Question 2: (astaxanthin, bioavailability), (astaxanthin, photostability), (astaxanthin, biological activities), (glycosylation, astaxanthin), (glycosylation, bioavailability), (glycosylation, photostability), (glycosylation, biological activities), (Yarrowia lipolytica, astaxanthin), (Yarrowia lipolytica, glycosylated astaxanthin), (Yarrowia lipolytica, β-carotene), (Adonis aestivalis, HBFD), (Adonis aestivalis, CBFD), (HBFD, astaxanthin), (CBFD, astaxanthin), (CBFD, β-carotene), (HBFD, β-carotene), (β-carotene, astaxanthin), (promoter, CBFD), (CBFD, astaxanthin production), (HBFD, astaxanthin production), (expressions of CBFD, astaxanthin production), (expressions of HBFD, astaxanthin production), (crtX, glycosylated astaxanthin), (Pantoea ananatis, crtX), (Pantoea ananatis, glycosylated astaxanthin), (glycosylated astaxanthin, astaxanthin-producing strain), (glycosylated astaxanthin, yield), (yield, astaxanthin production).
# Progress: 29.67% completed
# Response for Row 28:
# Answer to Question 2: (cyanobacterium Synechococcus elongatus, sucrose), (cyanobacterium Synechococcus elongatus, co-cultures), (cyanobacterium Synechococcus elongatus, heterotrophic workhorses), (heterotrophic workhorses, sucrose), (heterotrophic workhorses, β-carotene), (heterotrophic workhorses, indigoidine), (encapsulation, growth interference), (encapsulation, cyanobacterial culture), (encapsulation, sucrose concentrations), (encapsulation, β-carotene), (encapsulation, indigoidine), (photo-bioreactor, cyanobacterium Synechococcus elongatus), (photo-bioreactor, heterotrophic workhorses), (photo-bioreactor, encapsulation), (photo-bioreactor, bioprocess optimization), (hydrogel beads, growth interference), (hydrogel beads, cyanobacterial culture), (hydrogel beads, indigoidine), (hydrogel beads, β-carotene), (hydrogel beads, microenvironment), (hydrogel beads, cell metabolism), (hydrogel beads, product recovery), (EDTA, product recovery), (cyanobacterial culture, heterotroph-containing hydrogels), (cyanobacterial culture, next batch of immobilized heterotrophs), (hydrogel beads, protein overexpression tests), (hydrogel beads, 13C-metabolite analysis), (hydrogel beads, favorable microenvironment), (sucrose, indigoidine), (sucrose, β-carotene), (indigoidine, β-carotene).
# Progress: 30.77% completed
# Response for Row 29:
# Answer to Question 2: (host metabolism, desired compounds), (host metabolism, host cells), (host metabolism, overproducing strains), (Yarrowia lipolytica, bioproduction ability), (Yarrowia lipolytica, new value-added molecules), (Yarrowia lipolytica, human food), (Yarrowia lipolytica, disease treatment), (new synthetic tools, enzymes), (new enzymes, biotechnological importance), (metabolic events, substrate utilization), (metabolic events, recombinant protein production), (Yarrowia lipolytica, feed), (Yarrowia lipolytica, disease control), (Yarrowia lipolytica, food industry), (Yarrowia lipolytica, bioconversion of food waste), (Yarrowia lipolytica, single-cell protein), (biolipids, Yarrowia lipolytica), (new value-added molecules, Yarrowia lipolytica), (Yarrowia lipolytica, immune system regulation).
# Progress: 31.87% completed
# Response for Row 30:
# Answer to Question 2: (β-carotene, Yarrowia lipolytica), (Yarrowia lipolytica, β-carotene), (Yarrowia lipolytica, gene targets), (gene targets, β-carotene), (gene targets, lipid metabolism), (gene targets, sterol metabolism), (gene targets, signal transduction), (gene targets, stress response), (fatty acid oxidation, β-carotene), (lipid composition, β-carotene), (sterol transcriptional regulation, β-carotene), (4CL-8, β-carotene), (GCS, β-carotene), (YIsterTF, β-carotene), (disruption of genes, β-carotene), (high-throughput screening, β-carotene), (high-throughput screening, gene targets), (high-β-carotene production, β-carotene), (high-β-carotene production, Yarrowia lipolytica), (flow cytometry, screening efficiency), (screening efficiency, β-carotene), (screening efficiency, gene targets), (metabolic engineering, β-carotene), (metabolic engineering, gene targets).
# Progress: 32.97% completed
# Response for Row 31:
# Answer to Question 2: (beta-carotene, astaxanthin), (Yarrowia lipolytica, astaxanthin), (Yarrowia lipolytica, β-carotene), (CrtW, β-carotene), (CrtZ, β-carotene), (CrtW, astaxanthin), (CrtZ, astaxanthin), (CrtW, Yarrowia lipolytica), (CrtZ, Yarrowia lipolytica), (CrtW, CrtZ), (PspCrtW, β-carotene), (HpCrtZ, β-carotene), (PspCrtW, astaxanthin), (HpCrtZ, astaxanthin), (PspCrtW, Yarrowia lipolytica), (HpCrtZ, Yarrowia lipolytica), (PspCrtW, CrtZ), (HpCrtZ, CrtZ), (biomass, astaxanthin), (biomass, Yarrowia lipolytica), (expression, CrtW), (expression, CrtZ), (uracil/leucine biosynthesis, astaxanthin), (uracil/leucine biosynthesis, Yarrowia lipolytica), (cell metabolism, astaxanthin), (cell metabolism, Yarrowia lipolytica), (pathway modification, astaxanthin), (pathway modification, Yarrowia lipolytica), (transcriptome information, astaxanthin), (transcriptome information, Yarrowia lipolytica), (strain DN30, astaxanthin), (strain DN30, Yarrowia lipolytica), (fermenter, astaxanthin), (fermenter, Yarrowia lipolytica), (fermenter, strain DN30).
# Progress: 34.07% completed
# Response for Row 32:
# Answer to Question 2: (yarrowia lipolytica, metabolic engineering host), (yarrowia lipolytica, hydrocarbons), (yarrowia lipolytica, fatty acids), (yarrowia lipolytica, glycerol), (yarrowia lipolytica, renewable carbon sources), (yarrowia lipolytica, hyphal state), (hyphal state, biosynthetic activity), (hyphal state, oxygen mass transfer), (hyphal state, nutrient mass transfer), (hyphal state, culture viscosity), (mutations, hyphal formation), (genetic knockouts, hyphal morphology), (genome-wide CRISPR screen, genetic knockouts), (CRISPR screen, hyphal morphology), (ΔRAS2, hyphal formation), (ΔRAS2, engineered lycopene production strain), (ΔRAS2, multiday culture), (ΔRAS2, lycopene production), (ΔRAS2, genetic disruption), (lycopene production, heterologous pathway), (lycopene production, carbon flux), (carbon flux, mevalonate pathway), (ΔRAS2 mutant, metabolic engineering host), (ΔRAS2 mutant, carotenoids production), (ΔRAS2 mutant, biochemical production).
# Progress: 35.16% completed
# Response for Row 33:
# Answer to Question 2: (oleaginous yeast Yarrowia lipolytica, biolipid production), (oleaginous yeast Yarrowia lipolytica, lipid accumulation), (genetic engineering, production), (genetic engineering, metabolism), (synthetic biology, production), (synthetic biology, metabolism), (cloning, expression system), (cloning, research), (expression system, research), (Golden Gate cloning strategy, multigene expression vectors), (Golden Gate cloning strategy, Y. lipolytica), (multigene expression vectors, Y. lipolytica), (heterologous expression, carotenoid pathway), (heterologous expression, genes), (heterologous expression, β-carotene), (genes, β-carotene), (genes, carotenoid pathway), (Y. lipolytica, β-carotene), (Y. lipolytica, carotenoid pathway).
# Progress: 36.26% completed
# Response for Row 34:
# Answer to Question 2: (growth conditions, retinol production), (growth conditions, retinal production), (Yarrowia lipolytica, retinol production), (Yarrowia lipolytica, retinal production), (β-carotene 15,15'-dioxygenase, retinol), (β-carotene 15,15'-dioxygenase, retinal), (retinol dehydrogenase, retinol), (retinol dehydrogenase, retinal), (β-carotene-producing strain, retinol production), (β-carotene-producing strain, retinal production), (GGS1<sup>F43I</sup>, retinol production), (GGS1<sup>F43I</sup>, retinal production), (FAD1, retinol production), (FAD1, retinal production), (deletion of genes, retinol production), (deletion of genes, retinal production), (Mb.Blh, retinol production), (Mb.Blh, retinal production), (retinol, retinal), (retinol, β-carotene), (β-carotene, retinal), (BHT, retinol production), (BHT, retinal production), (GSH2, retinol production), (GSH2, retinal production), (retinol, lipid droplets), (retinol, extraction using Tween 80), (extraction using Tween 80, retinol production), (CJ2104, retinol production), (CJ2104, retinal production), (bioprocess conditions, retinol production), (bioprocess conditions, retinal production).
# Progress: 37.36% completed
# Response for Row 35:
# Answer to Question 2: (oleaginous yeast Yarrowia lipolytica, chemical production), (Yarrowia lipolytica, CRISPR-based gene expression toolkit), (CRISPR-based gene expression toolkit, gene expression), (integration sites, gene expression), (integration sites, Yarrowia lipolytica), (promoters, gene expression), (terminators, gene expression), (genetic components, gene expression), (genetic components, Yarrowia lipolytica), (integration efficiency, gene expression), (lycopene biosynthesis pathway, gene expression), (lycopene production, gene expression), (lycopene production, Yarrowia lipolytica), (gene expression, Yarrowia lipolytica), (promoters, Yarrowia lipolytica), (terminators, Yarrowia lipolytica), (integration sites, lycopene production), (genetic components, lycopene production), (promoters, lycopene production), (terminators, lycopene production).
# Progress: 38.46% completed
# Response for Row 36:
# Answer to Question 2: (growth rate, Y. lipolytica), (growth rate, S. cerevisiae), (production capability, β-carotene), (production capability, succinate), (β-carotene, Y. lipolytica), (succinic acid, S. cerevisiae), (gene deletions, Y. lipolytica), (gene deletions, S. cerevisiae), (gene knockout, function of genes), (GPH1 gene, S. cerevisiae), (GPH1 gene, isocitrate lyase enzyme), (isocitrate lyase enzyme, succinate), (isocitrate lyase enzyme, isocitrate), (gene knockout, metabolic constraints), (gene knockout, essential genes), (gene knockout, in vitro processes), (gene knockout, multiobjective optimization), (chromosomes, gene knockout), (chromosomes, strains), (strains, metabolic capacity), (strains, performance), (strains, β-carotene), (strains, succinate), (multiobjective optimization, metabolic engineering processes), (multiobjective optimization, strains), (multiobjective optimization, gene deletions), (multiobjective optimization, growth rate), (multiobjective optimization, production capability).
# Progress: 39.56% completed
# Response for Row 37:
# Answer to Question 2: (ABA, Botrytis cinerea), (ABA, Yarrowia lipolytica), (Botrytis cinerea, Yarrowia lipolytica), (BcABA1, ABA), (BcABA2, ABA), (BcABA3, ABA), (BcABA4, ABA), (BcCPR1, ABA), (Yarrowia lipolytica, ABA), (Yarrowia lipolytica, mevalonate flux), (mevalonate flux, ABA), (BcABA1, Yarrowia lipolytica), (BcABA2, Yarrowia lipolytica), (BcABA3, Yarrowia lipolytica), (BcABA4, Yarrowia lipolytica), (BcCPR1, Yarrowia lipolytica), (Yarrowia lipolytica, ABA titer), (Yarrowia lipolytica, biomass level), (bioreactor cultivation, ABA), (bioreactor cultivation, biomass level), (bioreactor cultivation, Yarrowia lipolytica), (bioreactor cultivation, ABA titer), (ABA titer, biomass level), (ABA titer, Yarrowia lipolytica), (bioprocess conditions, Yarrowia lipolytica), (bioprocess conditions, ABA), (bioprocess conditions, ABA titer), (bioprocess conditions, biomass level).
# Progress: 40.66% completed
# Response for Row 38:
# Answer to Question 2: (haematococcus pluvialis, astaxanthin), (xanthopyllomyces dendrorhous, astaxanthin), (haematococcus pluvialis, yield), (xanthopyllomyces dendrorhous, yield), (haematococcus pluvialis, cost), (xanthopyllomyces dendrorhous, cost), (escherichia coli, astaxanthin), (saccharomyces cerevisiae, astaxanthin), (yarrowia lipolytica, astaxanthin), (escherichia coli, yield), (saccharomyces cerevisiae, yield), (yarrowia lipolytica, yield), (escherichia coli, cost), (saccharomyces cerevisiae, cost), (yarrowia lipolytica, cost), (astaxanthin, health benefits), (astaxanthin, applications), (astaxanthin, food industry), (astaxanthin, pharmaceutical industry), (astaxanthin, microbial cell factories), (microbial cell factories, yield), (microbial cell factories, cost), (biotechnological progresses, astaxanthin), (biotechnological progresses, microbial cell factories), (biotechnological progresses, yield), (biotechnological progresses, cost), (biotechnological progresses, fermentation process control), (fermentation process control, astaxanthin), (fermentation process control, yield), (fermentation process control, cost).
# Progress: 41.76% completed
# Response for Row 39:
# Answer to Question 2: (astaxanthin, performance), (astaxanthin, Yarrowia lipolytica), (astaxanthin, bioprocess conditions), (3S,3'S-isomer, performance), (3S,3'S-isomer, Yarrowia lipolytica), (3S,3'S-isomer, bioprocess conditions), (Yarrowia lipolytica, performance), (Yarrowia lipolytica, bioprocess conditions), (bioprocess conditions, performance), (HpCrtW, astaxanthin), (HpCrtW, Yarrowia lipolytica), (HpCrtW, bioprocess conditions), (HpCrtZ, astaxanthin), (HpCrtZ, Yarrowia lipolytica), (HpCrtZ, bioprocess conditions), (CrtW, astaxanthin), (CrtW, Yarrowia lipolytica), (CrtW, bioprocess conditions), (CrtZ, astaxanthin), (CrtZ, Yarrowia lipolytica), (CrtZ, bioprocess conditions), (leucine biosynthesis, performance), (leucine biosynthesis, Yarrowia lipolytica), (leucine biosynthesis, bioprocess conditions), (biomass, performance), (biomass, Yarrowia lipolytica), (biomass, bioprocess conditions), (gene integration, HpCrtW), (gene integration, HpCrtZ), (gene integration, Yarrowia lipolytica), (modular enzyme assembly, HpCrtW), (modular enzyme assembly, HpCrtZ), (modular enzyme assembly, Yarrowia lipolytica), (fed-batch conditions, astaxanthin), (fed-batch conditions, performance), (fed-batch conditions, Yarrowia lipolytica).
# Progress: 42.86% completed
# Response for Row 40:
# ...
# Progress: 83.52% completed
# Response for Row 77:
# Answer to Question 2: (genetically modified microbes, protein-based products), (genetically modified microbes, enzymes), (genetically modified microbes, antibodies), (genetically modified microbes, commodity compounds), (overexpression of multiple enzymes, performance), (overexpression of multiple enzymes, product synthesis), (metabolite drainage, performance), (metabolite drainage, product synthesis), (synthetic circuits, native pathways), (synthetic circuits, performance), (synthetic circuits, fermentation conditions), (heterologous pathways, native pathways), (heterologous pathways, performance), (heterologous pathways, fermentation conditions), (engineered enzymes, channeling capabilities), (engineered enzymes, metabolites), (engineered enzymes, diffusion barriers), (engineered enzymes, intermediate toxicity), (engineered hosts, laboratory conditions), (engineered hosts, industry), (genetic mutations, fermentation outcomes), (non-genetic cell-to-cell variations, fermentation outcomes), (synthetic biology strains, industrial performance), (synthetic biology strains, titer), (synthetic biology strains, yield), (synthetic biology strains, productivity), (species, metabolic strengths), (species, specific compounds), (Corynebacterium glutamicum, TCA cycle-derived biosynthesis), (Yarrowia lipolytica, biosynthesis of fatty acids), (Yarrowia lipolytica, biosynthesis of carotenoids), (cyanobacteria, photosynthetic production), (cyanobacteria, sugar phosphate pathways), (Rhodococcus, biotransform recalcitrant feedstock), (emerging technologies, novel cell factories), (emerging technologies, genome-to-phenome mapping), (emerging technologies, single cell methods), (emerging technologies, knowledge engineering).
# Progress: 84.62% completed
# Response for Row 78:
# Answer to Question 2: (yarrowia lipolytica, lycopene), (lycopene, adenosine triphosphate), (lycopene, nicotinamide adenine dinucleotide phosphate), (adenosine triphosphate, lycopene), (nicotinamide adenine dinucleotide phosphate, lycopene), (adenosine triphosphate, yarrowia lipolytica), (nicotinamide adenine dinucleotide phosphate, yarrowia lipolytica), (adenosine triphosphate, fermentation process), (nicotinamide adenine dinucleotide phosphate, fermentation process), (fermentation process, yarrowia lipolytica), (optimized method, fermentation process), (optimized method, yarrowia lipolytica), (optimized method, lycopene), (optimized method, adenosine triphosphate), (optimized method, nicotinamide adenine dinucleotide phosphate).
# Progress: 85.71% completed
# Response for Row 79:
# Answer to Question 2: (heterologous crt genes, metabolome profiling), (heterologous crt genes, pathway abundance), (heterologous crt genes, Yarrowia lipolytica), (metabolome profiling, pathway abundance), (metabolome profiling, Yarrowia lipolytica), (pathway abundance, Yarrowia lipolytica), (crt genes, pathway abundance), (crt genes, Yarrowia lipolytica), (lycopene, fructose metabolism), (lycopene, mannose metabolism), (lycopene, citrate cycle), (lycopene, glyoxylate metabolism), (lycopene, dicarboxylate metabolism), (lycopene, glycerophospholipid metabolism), (lycopene, amino acid biosynthesis), (lycopene, valine metabolism), (lycopene, leucine metabolism), (lycopene, isoleucine metabolism), (fructose metabolism, Yarrowia lipolytica), (mannose metabolism, Yarrowia lipolytica), (citrate cycle, Yarrowia lipolytica), (glyoxylate metabolism, Yarrowia lipolytica), (dicarboxylate metabolism, Yarrowia lipolytica), (glycerophospholipid metabolism, Yarrowia lipolytica), (amino acid biosynthesis, Yarrowia lipolytica), (valine metabolism, Yarrowia lipolytica), (leucine metabolism, Yarrowia lipolytica), (isoleucine metabolism, Yarrowia lipolytica).
# Progress: 86.81% completed
# Response for Row 80:
# Answer to Question 2: (β-carotene, Yarrowia lipolytica), (acetyl-CoA, β-carotene), (11 genes, β-carotene), (strong promoters, β-carotene), (multiple gene copies, β-carotene), (fed-batch fermentation, β-carotene), (optimized medium, β-carotene), (engineered pathway, β-carotene), (engineered pathway, Yarrowia lipolytica), (Yarrowia lipolytica, lipid droplets), (Yarrowia lipolytica, squalene production), (Yarrowia lipolytica, hydrophobic terpenoid production), (β-carotene, lipid droplets), (squalene production, Yarrowia lipolytica), (hydrophobic terpenoid production, Yarrowia lipolytica).
# Progress: 87.91% completed
# Response for Row 81:
# Answer to Question 2: (carS, Yarrowia lipolytica), (carS, β-carotene), (phytoene synthase, β-carotene), (phytoene dehydrogenase, β-carotene), (lycopene β-cyclase, β-carotene), (GGS1, β-carotene), (GGS1, Yarrowia lipolytica), (P_GPD, carS), (ura3, carS), (DNA assembler method, integration efficiency), (ku70, integration efficiency), (ku80, integration efficiency), (ku70, NHEJ), (ku80, NHEJ), (integration efficiency, β-carotene), (integration efficiency, Yarrowia lipolytica), (Yarrowia lipolytica, β-carotene), (Yarrowia lipolytica, NHEJ), (NHEJ, β-carotene), (NHEJ, Yarrowia lipolytica).
# Progress: 89.01% completed
# Response for Row 82:
# Answer to Question 2: (golden gate modular cloning strategy, Yarrowia lipolytica), (golden gate modular cloning strategy, DNA assembly platform), (golden gate modular cloning strategy, synthetic pathway of carotenoid production), (DNA assembly platform, Yarrowia lipolytica), (DNA assembly platform, synthetic pathway of carotenoid production), (Yarrowia lipolytica, synthetic pathway of carotenoid production), (DNA modules, Yarrowia lipolytica), (DNA modules, synthetic pathway of carotenoid production), (regulatory elements, golden gate bricks), (selection markers, golden gate bricks), (golden gate bricks, synthetic pathway of carotenoid production), (golden gate bricks, Yarrowia lipolytica), (selection marker gene, genomic integration targeting sequences), (selection marker gene, Yarrowia lipolytica), (genomic integration targeting sequences, Yarrowia lipolytica), (promoter, gene), (promoter, terminator), (gene, terminator), (promoter, selection marker gene), (promoter, genomic integration targeting sequences), (gene, selection marker gene), (gene, genomic integration targeting sequences), (terminator, selection marker gene), (terminator, genomic integration targeting sequences).
# Progress: 90.11% completed
# Response for Row 83:
# Answer to Question 2: (enzyme, free carotenoids), (enzyme, Tagetes erecta), (enzyme, Yarrowia lipolytica), (Tagetes erecta, free carotenoids), (Tagetes erecta, Yarrowia lipolytica), (Yarrowia lipolytica, free carotenoids), (Yarrowia lipolytica, marigold oleoresin), (marigold oleoresin, free carotenoids), (marigold oleoresin, Yarrowia lipolytica), (lipases, free carotenoids), (lipases, Yarrowia lipolytica), (lipases, Rhizopus oryzae), (Rhizopus oryzae, free carotenoids), (Rhizopus oryzae, Yarrowia lipolytica), (bioprocess conditions, free carotenoids), (bioprocess conditions, Yarrowia lipolytica), (bioprocess conditions, marigold oleoresin), (bioprocess conditions, lipases), (bioprocess conditions, Tagetes erecta), (bioprocess conditions, Rhizopus oryzae), (Yarrowia lipolytica, biomass), (bioprocess conditions, biomass), (biomass, free carotenoids).
# Progress: 91.21% completed
# Response for Row 84:
# Answer to Question 2: (yeast Yarrowia lipolytica, lipid-based chemicals), (yeast Yarrowia lipolytica, modified genes), (modified genes, genomic integration), (modified genes, yeast Yarrowia lipolytica), (genomic integration, yeast Yarrowia lipolytica), (CRISPR-Cas9-based tool, gene integration), (CRISPR-Cas9-based tool, yeast Yarrowia lipolytica), (genomic loci, gene integrations), (genomic loci, yeast Yarrowia lipolytica), (gene integrations, cell growth), (gene integrations, genomic loci), (expression levels, GFP expression cassette), (GFP expression cassette, AXP), (GFP expression cassette, XPR2), (GFP expression cassette, A08), (GFP expression cassette, D17), (GFP expression cassette, MFE1), (standardized tool, gene integration), (standardized tool, plasmids), (plasmids, gene integration), (plasmids, yeast Yarrowia lipolytica), (lycopene biosynthesis pathway, gene integration), (lycopene biosynthesis pathway, modified genes), (lycopene biosynthesis pathway, yeast Yarrowia lipolytica), (marker recovery, gene integration), (marker recovery, yeast Yarrowia lipolytica), (expression levels, gene integration), (expression levels, genomic loci), (expression levels, yeast Yarrowia lipolytica), (gene integration, pathway engineering), (pathway engineering, yeast Yarrowia lipolytica).
# Progress: 92.31% completed
# Response for Row 85:
# Answer to Question 2: (Yarrowia lipolytica, metabolic engineering), (Yarrowia lipolytica, internal pathways), (Yarrowia lipolytica, new pathways), (Yarrowia lipolytica, platform cell factory), (Yarrowia lipolytica, cost-effective production), (Yarrowia lipolytica, chemicals), (Yarrowia lipolytica, fuels), (Yarrowia lipolytica, fatty acids), (Yarrowia lipolytica, lipids), (Yarrowia lipolytica, acetyl-CoA), (metabolic engineering, internal pathways), (metabolic engineering, new pathways), (metabolic engineering, platform cell factory), (metabolic engineering, cost-effective production), (metabolic engineering, chemicals), (metabolic engineering, fuels), (metabolic engineering, fatty acids), (metabolic engineering, lipids), (metabolic engineering, acetyl-CoA), (internal pathways, new pathways), (internal pathways, platform cell factory), (internal pathways, cost-effective production), (internal pathways, chemicals), (internal pathways, fuels), (internal pathways, fatty acids), (internal pathways, lipids), (internal pathways, acetyl-CoA), (new pathways, platform cell factory), (new pathways, cost-effective production), (new pathways, chemicals), (new pathways, fuels), (new pathways, fatty acids), (new pathways, lipids), (new pathways, acetyl-CoA), (platform cell factory, cost-effective production), (platform cell factory, chemicals), (platform cell factory, fuels), (platform cell factory, fatty acids), (platform cell factory, lipids), (platform cell factory, acetyl-CoA), (cost-effective production, chemicals), (cost-effective production, fuels), (cost-effective production, fatty acids), (cost-effective production, lipids), (cost-effective production, acetyl-CoA), (chemicals, fuels), (chemicals, fatty acids), (chemicals, lipids), (chemicals, acetyl-CoA), (fuels, fatty acids), (fuels, lipids), (fuels, acetyl-CoA), (fatty acids, lipids), (fatty acids, acetyl-CoA), (lipids, acetyl-CoA).
# Progress: 93.41% completed
# Response for Row 86:
# Answer to Question 2: (gene integration method, β-carotene biosynthesis pathway), (gene integration method, Yarrowia lipolytica), (β-carotene biosynthesis pathway, Yarrowia lipolytica), (gene integration method, performance), (β-carotene biosynthesis pathway, performance), (Yarrowia lipolytica, performance), (gene integration method, efficiency), (β-carotene biosynthesis pathway, efficiency), (Yarrowia lipolytica, efficiency), (gene integration method, production), (β-carotene biosynthesis pathway, production), (Yarrowia lipolytica, production), (efficiency, performance), (production, performance), (production, Yarrowia lipolytica).
# Progress: 94.51% completed
# Response for Row 87:
# Answer to Question 2: (lipase, vitamin A palmitate), (lipase, PEI-modified magnetic nanoparticles), (lipase, conversion rate), (lipase, reuse), (PEI-modified magnetic nanoparticles, vitamin A palmitate), (PEI-modified magnetic nanoparticles, conversion rate), (PEI-modified magnetic nanoparticles, reuse), (conversion rate, reuse), (conversion rate, vitamin A palmitate), (conversion rate, lipase), (conversion rate, PEI-modified magnetic nanoparticles).
# Progress: 95.60% completed
# Response for Row 88:
# Answer to Question 2: (crtB, Yarrowia lipolytica), (crtI, Yarrowia lipolytica), (crtB, lycopene), (crtI, lycopene), (GGS1, lycopene), (HMG1, lycopene), (GGS1, Yarrowia lipolytica), (HMG1, Yarrowia lipolytica), (POX1, Yarrowia lipolytica), (POX2, Yarrowia lipolytica), (POX3, Yarrowia lipolytica), (POX4, Yarrowia lipolytica), (POX5, Yarrowia lipolytica), (POX6, Yarrowia lipolytica), (GUT2, Yarrowia lipolytica), (POX1, POX6), (GUT2, POX1), (GUT2, POX6), (POX1, lycopene), (POX2, lycopene), (POX3, lycopene), (POX4, lycopene), (POX5, lycopene), (POX6, lycopene), (GUT2, lycopene), (lipid bodies, lycopene), (lipid bodies, Yarrowia lipolytica), (lipid bodies, GGS1), (lipid bodies, HMG1), (lipid bodies, crtB), (lipid bodies, crtI), (growth-limiting conditions, lycopene), (growth-limiting conditions, Yarrowia lipolytica), (specific lycopene content, lycopene), (specific lycopene content, Yarrowia lipolytica), (fed-batch cultures, lycopene), (fed-batch cultures, Yarrowia lipolytica), (yield, lycopene), (yield, Yarrowia lipolytica), (yield, fed-batch cultures).
# Progress: 96.70% completed
# Response for Row 89:
# Answer to Question 2: (β-carotene, Yarrowia lipolytica), (β-carotene, nutritional supplement), (β-carotene, genotoxicity), (β-carotene, subchronic toxicity), (Yarrowia lipolytica, nutritional supplement), (Yarrowia lipolytica, genotoxicity), (Yarrowia lipolytica, subchronic toxicity), (genotoxicity, Salmonella typhimurium), (genotoxicity, Escherichia coli), (genotoxicity, Chinese Hamster Ovary WBL cells), (genotoxicity, CD-1 mice), (subchronic toxicity, SD rats), (subchronic toxicity, β-carotene), (subchronic toxicity, clinical pathology), (subchronic toxicity, gross- and histopathological evaluations), (NOAEL, β-carotene), (NOAEL, Yarrowia lipolytica), (β-carotene, clinical pathology), (β-carotene, gross- and histopathological evaluations), (Yarrowia lipolytica, clinical pathology), (Yarrowia lipolytica, gross- and histopathological evaluations), (genotoxicity, NOAEL), (subchronic toxicity, NOAEL).
# Progress: 97.80% completed
# Response for Row 90:
# Answer to Question 2: (gene crtE, lycopene biosynthesis), (gene crtB, lycopene biosynthesis), (gene crtI, lycopene biosynthesis), (gene crtE, Yarrowia lipolytica), (gene crtB, Yarrowia lipolytica), (gene crtI, Yarrowia lipolytica), (Yarrowia lipolytica, lycopene biosynthesis), (Yarrowia lipolytica, lipid accumulation conditions), (lycopene biosynthesis, lipid accumulation conditions), (gene crtE, lipid accumulation conditions), (gene crtB, lipid accumulation conditions), (gene crtI, lipid accumulation conditions), (Yarrowia lipolytica, lipid-derived compounds), (lycopene, lipid-derived compounds).
# Progress: 98.90% completed
# Response for Row 91:
# Answer to Question 2: (oleochemical industry, biotechnology), (biotechnology, biosurfactants), (biotechnology, lipases), (lipases, detergents), (lipases, biofuel production), (lipid substrates, biotechnological applications), (lipid substrates, nutritional products), (lipid substrates, pharmacological products), (Yarrowia lipolytica, microbial factory), (Yarrowia lipolytica, lipid metabolism), (Yarrowia lipolytica, lipid-derived compounds), (lipid metabolism, lipid-derived compounds), (lipid metabolism, wax esters), (lipid metabolism, isoprenoid-derived compounds), (lipid metabolism, polyhydroxyalkanoates), (lipid metabolism, free hydroxylated fatty acids), (lipid stocks, substrates), (lipid stocks, Yarrowia lipolytica), (mutant strains, Yarrowia lipolytica), (recombinant strains, Yarrowia lipolytica), (mutant strains, lipid metabolism), (recombinant strains, lipid metabolism), (lipid stocks, composition), (lipid stocks, yields), (composition, added-value products), (yields, added-value products).
# Progress: 100.00% completed

# %% [markdown]
# **Step 3: Combine entities with similar meanings**

# %%
import pandas as pd
import re
import numpy as np
import concurrent.futures
import openai
import os

##################################################
# 1) READ EXCEL AND EXTRACT ENTITIES (UNCHANGED)
##################################################
df = pd.read_excel(output_file_path, engine="openpyxl")
df["Extracted entities"] = df["Extracted entities"].fillna("")
column_values = df["Extracted entities"].astype(str).tolist()

pattern = r"\(([^,]+), ([^)]+)\)"
entities = []
for value in column_values:
    matches = re.findall(pattern, value)
    for (e1, e2) in matches:
        entities.append(e1)
        entities.append(e2)

# Remove duplicates while preserving order
entities = list(dict.fromkeys(entities))

##################################################
# 2) UPDATED OPENAI EMBEDDINGS IMPLEMENTATION
##################################################

def get_openai_embedding(text, model="text-embedding-3-small"):
    """Get embedding with proper error handling and API parameters"""
    try:
        response = client.embeddings.create(
            input=text,
            model=model,
            encoding_format="float"  # Explicitly request float format
        )
        return response.data[0].embedding
    except openai.APIError as e:
        print(f"API Error: {e.status_code} - {e.message}")
    except Exception as e:
        print(f"General error embedding '{text[:20]}...': {str(e)}")
    return None

# --- PARALLEL EMBEDDING REQUESTS WITH RATE LIMIT HANDLING ---
model_name = "text-embedding-3-small"  # Can change to "text-embedding-ada-002" for older model
all_embeddings = []

# Reduced max_workers to comply with OpenAI rate limits
with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
    future_to_entity = {
        executor.submit(get_openai_embedding, ent, model_name): ent 
        for ent in entities
    }

    for future in concurrent.futures.as_completed(future_to_entity):
        ent = future_to_entity[future]
        try:
            emb = future.result()
            all_embeddings.append((ent, emb))
        except Exception as e:
            print(f"Error processing '{ent}': {e}")
            all_embeddings.append((ent, None))

# Create embedding dictionary maintaining original entity order
emb_dict = dict(all_embeddings)
vectors = []
for ent in entities:
    emb_vec = emb_dict.get(ent)
    if emb_vec is not None:
        vectors.append(np.array(emb_vec, dtype=np.float32))
    else:
        vectors.append(None)

##################################################
# 3) COSINE SIMILARITY (VECTORIZED IN NUMPY)
##################################################
# Ensure a consistent dimensionality by replacing missing embeddings with zeros
valid_vectors = [v for v in vectors if v is not None]
if not valid_vectors:
    print("No valid embeddings found, cannot proceed.")
    sys.exit(1)  # Exit the script gracefully

dim = len(valid_vectors[0])
for i, v in enumerate(vectors):
    if v is None:
        vectors[i] = np.zeros(dim, dtype=np.float32)

# Create a 2D array with shape (N, D)
matrix = np.stack(vectors)

# Compute cosine similarity matrix
dot_matrix = matrix @ matrix.T
norms = np.linalg.norm(matrix, axis=1, keepdims=True)
denom = norms @ norms.T
similarity_matrix = dot_matrix / denom

threshold = 0.8
N = len(entities)
similar_phrases = {}

# Use np.triu_indices to consider unique pairs (i < j)
upper_indices = np.triu_indices(N, k=1)
sim_vals = similarity_matrix[upper_indices]
above_thresh = np.where(sim_vals > threshold)[0]

for idx in above_thresh:
    i = upper_indices[0][idx]
    j = upper_indices[1][idx]
    # Consider entity j as similar to entity i
    similar_phrases[entities[j]] = entities[i]

##################################################
# 4) REPLACE SIMILAR PHRASES IN THE DATAFRAME
##################################################
total_rows = len(df)
for row_idx in range(total_rows):
    if row_idx % 100 == 0 or row_idx == total_rows - 1:
        print(f"Progress: {100.0 * row_idx / total_rows:.1f}%")
    
    cell_value = str(df.at[row_idx, "Extracted entities"])
    
    # Skip rows containing "Yarrowia"
    if "Yarrowia" in cell_value:
        continue
    
    for similar, original in similar_phrases.items():
        # Also skip if "Yarrowia" appears in the phrase itself
        if "Yarrowia" in similar:
            continue
        if similar in cell_value:
            cell_value = cell_value.replace(similar, original)
    
    df.at[row_idx, "Extracted entities"] = cell_value

modified_file_path = f'modified_{output_file_path}'
df.to_excel(modified_file_path, index=False, engine="openpyxl")
print(f"Processing complete. Modified file saved to: {modified_file_path}")
# Out:
# Progress: 0.0%
# Progress: 98.9%
# Processing complete. Modified file saved to: modified_updated(GPT-4o)_yarrowia carotene_causal.xlsx

# %% [markdown]
# **Step 4.1: Plot knowledge graph**

# %%
from pyvis.network import Network
import pandas as pd
import re
import networkx as nx

# Load the Excel file
filepath = modified_file_path
df = pd.read_excel(filepath, engine='openpyxl')

# Initialize NetworkX Graph
G = nx.Graph()

# Nodes to exclude
words_to_exclude = []

# Regular expression to match the pattern (entity A, entity B)
pattern = r'\(([^,]+), ([^\)]+)\)'

# Iterate over the DataFrame rows to extract entity pairs and their sources
for _, row in df.iterrows():
    value = row['Extracted entities']
    source = row['Title']  # Extract source for each pair

    matches = re.findall(pattern, value)
    for entity_a, entity_b in matches:
        # Check if any word to exclude is part of the entity names
        if not any(word in entity_a for word in words_to_exclude) and not any(word in entity_b for word in words_to_exclude):
            G.add_node(entity_a, label=entity_a)
            G.add_node(entity_b, label=entity_b)
            G.add_edge(entity_a, entity_b, title=source)

def search_network(graph, keywords, depth=1):
    # Ensure all keywords are lowercase for case-insensitive search
    keyword_list = [kw.lower() for kw in keywords]

    # Helper function to check if a node label contains all keywords
    def contains_all_keywords(label):
        return all(kw in label.lower() for kw in keyword_list)

    # Collect nodes that contain all keywords in their label
    nodes_of_interest = set()
    for node, attr in graph.nodes(data=True):
        if 'label' in attr and contains_all_keywords(attr['label']):
            nodes_of_interest.add(node)

    # Expand search to include neighbors up to the specified depth
    for _ in range(depth):
        neighbors = set()
        for node in nodes_of_interest:
            neighbors.update(nx.neighbors(graph, node))
        nodes_of_interest.update(neighbors)
    
    # Return a subgraph containing only relevant nodes and edges
    return graph.subgraph(nodes_of_interest).copy()

# Perform search with a list of keywords
word_combinations = ["carotene"]  # Replace with your keywords
filtered_graph = search_network(G, word_combinations)

# Extract node names from the filtered graph
node_names = list(filtered_graph.nodes())

# Prepare a simple text summary of node names
node_names_text = ", ".join(node_names)

# Now, `node_names_text` contains a clean, comma-separated list of node names, ready for summarization
print(node_names_text)

# Initialize Pyvis network with the filtered graph
net = Network(height="2160px", width="100%", bgcolor="#222222", font_color="white")
net.from_nx(filtered_graph)

# Continue with setting options and saving the network as before
net.set_options("""
{
  "physics": {
    "barnesHut": {
      "gravitationalConstant": -80000,
      "centralGravity": 0.5,
      "springLength": 75,
      "springConstant": 0.05,
      "damping": 0.09,
      "avoidOverlap": 0.5
    },
    "maxVelocity": 100,
    "minVelocity": 0.1,
    "solver": "barnesHut",
    "timestep": 0.3,
    "stabilization": {
        "enabled": true,
        "iterations": 500,
        "updateInterval": 10,
        "onlyDynamicEdges": false,
        "fit": true
    }
  },
  "nodes": {
    "font": {
      "size": 30,
      "color": "white"
    }
  }
}
""")

# Save and show the network
net.write_html('filtered_entity_' + "_".join(word_combinations) + '_network.html')
# Out:
# CarB, hexokinase activity, growth mediums, fermentation cycle, tHMG, heterologous pathway, hydrophobic substrates, enzyme fusion, carotenogenesis genes, total production, phytoene synthase, Yarrowia lipolytica, glucose based YP medium, β-carotene concentration, carotenes, protein engineering, native precursor supply, gene integration, wild-type strain, rate-limiting steps, sterol transcriptional regulation, NADPH regeneration, retinol, competitive producer organism, growth profile, metabolic balance, target product yield, extracellular export, β-carotene-producing Yarrowia lipolytica strains, integration efficiency, syngas-derived acetic acid, canola oil-containing yeast-peptone, mvaE, fatty acid oxidation, health functions, productivity, engineered strains, genes, genes of Mucor circinelloides, EasyClone, lycopene β-cyclase, transcriptional level of Hxk, heterotrophic workhorses, copy numbers of carRP, β-carotene ketolase, screening efficiency, bioreactors, β-carotene production chassis, genotoxicity, NOAEL, precursors, pentose phosphate pathway, crtI, colony-color spectrum, α-carotene, carS, Y.L-2, retinal production, transcriptional unit, acetic acid tolerance, production of lipophilic natural compounds, lipid composition, lipid body, production, glucose utilization, performance, β-carotene biosynthesis, 4CL-8, NADP<sup>+</sup>-dependent glyceraldehyde-3-phosphate dehydrogenase, FPP accumulation, carotenogenic genes, CrtE, efficiency, lipid pathway flux adjustment, subchronic toxicity, cofactors consumption, Saccharomyces cerevisiae, HpCrtZ, optimized strain, growth conditions, Y27R, hyphae, high-throughput screening, mevalonate, β-carotene producing strain, mvaS, tHMGR, engineered Yarrowia lipolytica, artificial sequences, β-Carotene yield, zeaxanthin, bifunctional phytoene synthase/lycopene cyclase, crtZ, concentration, β-carotene production, lipid content, bioreactor, bioreactor fermentations, gene expression, shake flask cultures, gene targets, promoter, genetic manipulation tools, fermentation time, accumulation of β-carotene, iterative overexpression, metabolic engineering, targeting, anti-cardiovascular properties, chemical synthesis, multigene cassette, CarRA, YPD cultures, subcellular organelles, acetic acid concentration, upcycler strain, canthaxanthin, protein knockdown, β-carotene synthesis related genes, URA3Δ strains IMUFRJ 50682, nutritional supplement, peroxisome, carRA, lipid biosynthesis pathway, morphological engineering, MVA pathway, glycerol, β-Carotene production, transcriptional factor, heterologous expression, phosphoketolase-phosphotransacetylase pathway, large-scale fermentation, beta-carotene, strong promoters, α-carotene titer, β-ionone, glucose, carotene production, glucose consumption, engineered strain Yli-CAH, overexpressing GGS1, astaxanthin, genetic engineering, triolein, HMG-CoA accumulation, erg13, β-carotene titer, mRNA level, controlled conditions, strains, oval-shaped yeast form, future engineering approaches, crtE, gene SPT15-like, lipid overproducer strain, NADP+/NADPH, teaching protocol, β-carotene producing Yarrowia lipolytica strain, encapsulation, codon-adapted CarB, antioxidant properties, oleaginous yeast Yarrowia lipolytica, gene integration method, Yarrowia lipolytica PO1h, mevalonate pathway, retinol production, pH effects, Yarrowia lipolytica PEX17-HA, morphological transition, crispr-iCas9, DID2, kinetic parameters, Blakeslea trispora, bioprocess conditions, biomass, citric acid, production titer, gene expression levels, deleting MHY1, HR, β-carotene biosynthetic pathway, fatty acid synthesis pathway, SQS1, β-carotene, optimized medium, β-Carotene, central carbon pathway engineering, promoters engineering, lycopene production-carotene compositions, zeaxanthin content, clinical pathology, biotechnological industry, high-β-carotene production, key nodes on the carotenoid pathway, quantification, overexpressing ERG13, lipophilic properties, GGS1/crtE, fed-batch fermentation,  ...

# %% [markdown]
# **Step 4.2: Produce summarization report**

# %%
from IPython.display import Markdown

def trim_text(text, max_length):
    if len(text) > max_length:
        return text[:max_length].rsplit(' ', 1)[0] + "..."  # Trim to max_length, avoid cutting words in half
    else:
        return text

# Apply the trimming function to node_names_text
cut_off_chunk_size = 5000
trimmed_node_names_text = trim_text(node_names_text, cut_off_chunk_size)
keyword = ", ".join(word_combinations)

# Construct the prompt with the potentially trimmed node_names_text
prompt = "These are the terms related to " + filepath + keyword + ", categorize them and write a summary report.   " + trimmed_node_names_text

messages = [
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": prompt}
]

try:
    # Use OpenAI's API directly
    response = client.chat.completions.create(
        model="gpt-4o",
        messages=messages,
        max_tokens=5000,
        timeout=30  # Timeout in seconds
    )
    response1 = response.choices[0].message.content
except Exception as e:
    print(f"API Error: {e}")
    response1 = "Failed to generate response"

display(Markdown(response1))
# Out:
# ### Summary Report on Carotene Production in Yarrowia lipolytica
#
# #### Categories:
# 1. **Genetic Engineering and Biotechnology:**
#    - **Genes and Pathways:** CarB, carotenogenesis genes, phytoene synthase, crtI, carRA, 11 genes in β-carotene synthesis pathway, CrtE, crtYB, crtZ, genes of Mucor circinelloides, CrtW, engineered pathway, heterologous expression, heterologous pathway.
#    - **Metabolic and Pathway Engineering:** MVA pathway, mevalonate pathway, central carbon pathway engineering, metabolic engineering, native precursor supply, acetyl-CoA, NADP+/NADPH, metabolic balance, key nodes on the carotenoid pathway, iterative overexpression, lipid biosynthesis pathway, upcycler strain.
#    - **Gene Manipulation Tools:** CRISPR/Cas9, gene integration, protein engineering, codon adaptation, gene integration method, NHEJ, EasyClone, gene expression, codon-adapted CarRA, codon-adapted CarB, protein knockdown.
#
# 2. **Fermentation and Cultivation Conditions:**
#    - **Cultivation Media:** YPD cultures, glucose based YP medium, glucose utilization, glucose consumption, acetic acid, syngas-derived acetic acid, canola oil-containing yeast-peptone, YNB flask cultures.
#    - **Fermentation Methods:** Bioreactors, shake flask cultures, bioreactor fermentations, controlled conditions, high-throughput screening, large-scale fermentation, DO-stat fed-batch fermentation.
#    - **Growth Conditions:** pH effects, optimal medium, temperature, substrate choice, bioprocess conditions, kinetic parameters, high-β-carotene production.
#
# 3. **Strain Development:**
#    - **Engineered Strains:** β-carotene-producing Yarrowia lipolytica strains, engineered Yarrowia lipolytica, engineered strain Yli-CAH, optimized strain, lipid overproducer strain, auxotrophic mutants IMUFRJ 50682, wild-type strain, engineered Yarrowia lipolytica strain.
#    - **Productivity and Efficiency:** Productivity, extraction yields, integration efficiency, rate-limiting steps, production titer, yield.
#
# 4. **Product Accumulation and Analysis:**
#    - **Carotenoids and Derivatives:** β-carotene, α-carotene, zeaxanthin, retinol, lycopene, canthaxanthin, β-ionone, astaxanthin, retinal.
#    - **Production Metrics:** Total production, β-carotene concentration, β-carotene yield, β-carotene titer, β-carotene biosynthetic pathway, β-carotene production chassis, accumulation of β-carotene.
#
# 5. **Functional Attributes and Applications:**
#    - **Health and Nutritional Benefits:** Health functions, anti-cardiovascular properties, antioxidant properties, nutritional supplement, clinical pathology.
#    - **Industrial and Biotechnological Applications:** Biotechnological industry, microbial cell factories, production of lipophilic natural compounds.
#
# 6. **Structural Biology and Enzyme Activity:**
#    - **Enzymes and Proteins:** Hexokinase activity, enzyme fusion, phytoene synthase, lycopene β-cyclase, bifunctional phytoene synthase/lycopene cyclase, β-carotene ketolase, HpCrtZ.
#    - **Gene Regulation and Expression:** Sterol transcriptional regulation, transcriptional level of Hxk, transcriptional unit, transcriptional factor, promoter, promoters engineering, gene targets.
#
# 7. **Safety and Toxicology:**
#    - **Toxicological Assessments:** Genotoxicity, subchronic toxicity, gross- and histopathological evaluations, NOAEL.
#
# #### Summary:
# The carotene production research in Yarrowia lipolytica spans various domains. Genetic and metabolic engineering strategies are leveraged to optimize carotenoid biosynthesis pathways. This involves manipulating specific genes and pathways like the MVA pathway and enhancing native precursor supply for improved productivity.
#
# Fermentation and cultivation strategies, including the choice of growth media and optimization of fermentation conditions, play a significant role in achieving high carotene yields. The productivity of β-carotene and related compounds is monitored through extraction yields and production titers, with emphasis on engineered and wild-type strains of Yarrowia lipolytica.
#
# Applications range from health-related benefits, such as antioxidant and anti-cardiovascular properties, to industrial applications in biotechnology for the production of lipophilic natural compounds.
#
# Finally, there is a focus on assessing the safety of these engineered strains, ensuring the absence of genotoxic effects through comprehensive toxicological evaluations.
