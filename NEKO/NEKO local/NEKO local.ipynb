# %% [markdown]
# **Step 1: Literature search and text collection**

# %%
# Search PubMed and get article abstracts

# pip install biopython pandas openpyxl

from Bio import Entrez
import pandas as pd

# Define your email to use with NCBI Entrez
Entrez.email = "your@email.com"

def search_pubmed(keyword):
    
    # Adjust the search term to focus on abstracts
    search_term = f"{keyword}[Abstract]"
    handle = Entrez.esearch(db="pubmed", term=search_term, retmax=500)
    record = Entrez.read(handle)
    handle.close()
    # Get the list of Ids returned by the search
    id_list = record["IdList"]
    return id_list

def fetch_details(id_list):
    ids = ','.join(id_list)
    handle = Entrez.efetch(db="pubmed", id=ids, retmode="xml")
    records = Entrez.read(handle)
    handle.close()

    # Create a list to hold our article details
    articles = []

    for pubmed_article in records['PubmedArticle']:
        article = {}
        article_data = pubmed_article['MedlineCitation']['Article']
        article['Title'] = article_data.get('ArticleTitle')
        
        # Directly output the abstract
        abstract_text = article_data.get('Abstract', {}).get('AbstractText', [])
        if isinstance(abstract_text, list):
            abstract_text = ' '.join(abstract_text)
        article['Abstract'] = abstract_text

        article['Journal'] = article_data.get('Journal', {}).get('Title')

        articles.append(article)

    return articles



# Example usage
keyword = "yarrowia carotene"
id_list = search_pubmed(keyword)
articles = fetch_details(id_list)

# Convert our list of articles to a DataFrame
df = pd.DataFrame(articles)

# Saving the DataFrame to an Excel file
excel_filename = keyword+"_pubmed_search_results.xlsx"
df.to_excel(excel_filename, index=False)

print(f"Saved search results to {excel_filename}")
# Out:
# Saved search results to yarrowia carotene_pubmed_search_results.xlsx

# %% [markdown]
# **Step 2: Entity and relationship extraction with LLM**

# %%
import pandas as pd
import os
import requests

def ask_questions(abstract, questions, system_prompts):
    responses = []
    for question, system_prompt in zip(questions, system_prompts):
        prompt_text = question + " " + str(abstract)
        messages = [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": prompt_text}
        ]
        
        try:
            # Use the OpenAI-compatible endpoint
            response = requests.post(
                'http://localhost:11434/v1/chat/completions',
                json={
                    'model': 'qwen2.5:14b',  # Verify model name with `ollama list`
                    'messages': messages,
                    'max_tokens': 5000,
                    'request_timeout': 10000  # Timeout in seconds
                }
            )
            response.raise_for_status()
            
            # Extract response in OpenAI-compatible format
            answer = response.json()['choices'][0]['message']['content']
            responses.append(answer.strip())
        except Exception as e:
            print(f"Error getting response: {e}")
            responses.append("")
    
    return responses

# ---------------------------------------------------
# Example usage reading from Excel and saving results
# ---------------------------------------------------

# Read the Excel file
file_path = excel_filename  # Replace with your file path
df = pd.read_excel(file_path)

questions = [" "]  # Maintain a placeholder for text structure
system_prompts = [
    "You are a specialized analyzer for scientific paper abstracts with a focus on identifying causal relationships between key entities in biological studies. Your primary task is to extract and identify all causal relationships present in an abstract between the following entities: Performance, Species, Genes, Methods of genetic engineering (such as knockout or expression), Enzymes, Proteins, and Bioprocess conditions (e.g., growth conditions). For each abstract provided, identify every causal relationship between these entities. You must consider all combinations, even indirect relationships, and output a long, detailed answer that includes every possible valid combination pair. Your output should strictly follow this format: (Entity A, Entity B), (Entity C, Entity D), ... with no additional text. Important Instructions: Comprehensiveness: Include all valid combinations of causal relationships found in the abstract; Detail: Ensure the output is long and detailed, listing every relationship pair even if some relationships may be indirectly connected; Format: Output only the pairs in the exact format described above with no additional explanations or commentary. Examples: Example 1: Abstract: The knockout of gene X significantly improved performance in species Y. Output: (gene X, performance), (gene X, species Y), (species Y, performance). Example 2: Abstract: Expression of enzyme Z in species W leads to increased protein levels under specific growth conditions. Output: (enzyme Z, protein levels), (enzyme Z, species W), (enzyme Z, growth conditions), (protein levels, species W), (protein levels, growth conditions), (species W, growth conditions). Example 3: Abstract: The study shows that a change in bioprocess conditions influences the expression of gene A, which in turn affects the performance of species B. Output: (bioprocess conditions, gene A), (bioprocess conditions, performance), (bioprocess conditions, species B), (gene A, performance), (gene A, species B), (performance, species B).",
]

# Process each abstract and store the response
total_rows = len(df)

for i, row in df.iterrows():
    os.system('cls' if os.name == 'nt' else 'clear')
    
    # Get response from Ollama
    response = ask_questions(row['Abstract'], [questions[0]], [system_prompts[0]])[0]
    df.at[i, 'Extracted entities'] = response
    
    print(f"Response for Row {i+1}:")
    print(f"Answer to Question 2: {response}")
    
    progress = ((i + 1) / total_rows) * 100
    print(f"Progress: {progress:.2f}% completed")

# Save the updated DataFrame
output_file_path = 'updated(Qwen2.5_14b)_' + keyword + '_causal.xlsx'
df.to_excel(output_file_path, index=False)
# Out:
# Response for Row 1:
# Answer to Question 2: (bioprocess conditions, performance), (bioprocess conditions, species Yarrowia lipolytica), (species Yarrowia lipolytica, performance), (lipid utilization, performance), (lipid utilization, species Yarrowia lipolytica), (growth rate, lipid accumulation), (growth rate, performance), (growth rate, species Yarrowia lipolytica), (lipid uptake, lipid accumulation), (lipid uptake, performance), (lipid uptake, species Yarrowia lipolytica), (lipid accumulation, performance), (lipid accumulation, species Yarrowia lipolytica)
# Progress: 1.10% completed
# Response for Row 2:
# Answer to Question 2: (squalene biosynthesis pathway, squalene production), (ABC transporters, squalene secretion), (OSH3, squalene secretion), (binding domain of OSH3, secretion signal peptide), (signal peptides, squalene secretion), (Yarrowia lipolytica, squalene production), (Yarrowia lipolytica, squalene secretion), (SNQ2, squalene secretion), (squalene biosynthesis pathway, Yarrowia lipolytica), (OSH3, β-carotene extracellular export), (signal peptides optimization, squalene production), (fed-batch cultivation, squalene secretion)
# Progress: 2.20% completed
# Response for Row 3:
# Answer to Question 2: (substrates, biomass yield), (substrates, lipid content), (substrates, β-carotene levels), (glycerol, biomass concentration), (glucose, lipid content), (acetic acid, lipid concentration), (glucose, β-carotene content per cell), (glycerol, overall β-carotene concentration), (substrate choice, Yarrowia lipolytica metabolite production)
# Progress: 3.30% completed
# Response for Row 4:
# Answer to Question 2: (β-carotene production, gene expression), (β-carotene production, bioprocess conditions), (enzyme activity, β-carotene production), (carbon and redox rebalancing, β-carotene production), (lycopene inhibition removal, β-carotene production), (pentose phosphate pathway, β-carotene production), (glyceraldehyde-3-phosphate dehydrogenase, β-carotene production), (phosphoketolase-phosphotransacetylase pathway, β-carotene production), (lipid biosynthesis, β-carotene production), (gene expression, performance), (enzyme activity, performance), (carbon and redox rebalancing, performance), (lycopene inhibition removal, performance), (pentose phosphate pathway, performance), (glyceraldehyde-3-phosphate dehydrogenase, performance), (phosphoketolase-phosphotransacetylase pathway, performance), (lipid biosynthesis, performance), (bioprocess conditions, performance), (gene expression, lipid biosynthesis), (enzyme activity, lipid biosynthesis), (carbon and redox rebalancing, lipid biosynthesis), (lycopene inhibition removal, lipid biosynthesis), (pentose phosphate pathway, lipid biosynthesis), (glyceraldehyde-3-phosphate dehydrogenase, lipid biosynthesis), (phosphoketolase-phosphotransacetylase pathway, lipid biosynthesis)
# Progress: 4.40% completed
# Response for Row 5:
# Answer to Question 2: (biocatalysts, performance), (biocatalysts, bioprocess conditions), (gene expression, performance), (gene expression, bioprocess conditions), (enzymes, performance), (enzymes, species Yarrowia lipolytica), (enzymes, growth conditions), (growth conditions, gene expression), (growth conditions, enzymes), (species Yarrowia lipolytica, performance), (species Yarrowia lipolytica, enzymes), (bioprocess conditions, performance), (crocetin biosynthesis pathway, species Yarrowia lipolytica), (temperature, enzyme activity), (fermentation media, enzymes), (fermentation conditions, performance), (gene expression, species Yarrowia lipolytica), (enzymes, gene expression)
# Progress: 5.49% completed
# Response for Row 6:
# Answer to Question 2: (co-culture, production), (co-culture, byproducts), (glucose, biomass), (glucose, citric acid), (citric acid, consumption), (citric acid, upcycler strain), (upcycler strain, glucose), (upcycler strain, citric acid), (minimal medium, co-culture), (hydrolysate, co-culture), (β-carotene, production), (byproducts, yield), (WT strain, biomass), (WT strain, citric acid), (biomass, WT strain), (citric acid, WT strain), (β-carotene, yield)
# Progress: 6.59% completed
# Response for Row 7:
# Answer to Question 2: (key genes in the mevalonate pathway, phytoene production), (key genes in the mevalonate pathway, Yarrowia lipolytica), (metabolic engineering approaches, phytoene synthesis), (glyoxylate cycle inhibition, peroxisomal acetyl-CoA accumulation), (peroxisomal acetyl-CoA accumulation, phytoene production), (engineered strains, phytoene production), (Yarrowia lipolytica, phytoene production), (increase in phytoene synthesis, flask-scale fed-batch culture titer), (increase in phytoene synthesis, yield per gram dry cell weight)
# Progress: 7.69% completed
# Response for Row 8:
# Answer to Question 2: (β-carotene hydroxylases, zeaxanthin), (β-carotene hydroxylases, β-cryptoxanthin), (genetic engineering, Yarrowia lipolytica), (Yarrowia lipolytica, zeaxanthin), (Yarrowia lipolytica, β-cryptoxanthin), (β-carotene hydroxylase from Chondromyces crocatus, β-cryptoxanthin), (endoplasmic reticulum targeting, zeaxanthin production), (peroxisomes targeting, zeaxanthin production), (multienzyme scaffold-free complexes, zeaxanthin titer), (RIDD and RIAD tags, conversion rate), (bioprocess conditions, enzyme activity), (enzymes, gene expression), (gene expression, carotenoid production), (performance, zeaxanthin titers)
# Progress: 8.79% completed
# Response for Row 9:
# Answer to Question 2: (β-carotene-producing Y. lipolytica strain XK17, expression of CCD gene), (CCD gene, β-ionone production), (rUinO-D14, high yielding strain), (promoter optimization, rUinO-D14), (mevalonate pathway genes, β-ionone production), (protein tagging strategy, mevalonate pathway genes expression), (heterologous oxidoreductase pathway, xylose utilization), (xylose, β-ionone production), (lignocellulosic hydrolysate, carbon source for Y. lipolytica), (Y. lipolytica NHA-A31 strain, high β-ionone productivity), (NHA-A31, lignocellulosic hydrolysate utilization), (CCD gene expression, strain optimization), (optimized mevalonate pathway genes, strain performance), (protein tagging strategy, strain performance), (heterologous oxidoreductase pathway, NHA-A31 strain), (bioprocess conditions, gene expression), (gene expression, bioprocess conditions), (gene expression, β-ionone production), (optimized bioprocess conditions, high yielding strain), (mevalonate pathway optimization, xylose utilization), (xylose utilization, sustainable β-ionone production)
# Progress: 9.89% completed
# Response for Row 10:
# Answer to Question 2: (synthetic biology tools, industrial chassis strains), (synthetic biology tools, yeast Yarrowia lipolytica), (synthetic biology tools, other yeasts of Yarrowia clade), (yeast Yarrowia lipolytica, fluorescent proteins), (yeast Yarrowia lipolytica, carotenoid pathway), (Golden Gate Y. lipolytica tool kit, fluorescent proteins), (Golden Gate Y. lipolytica tool kit, carotenoid pathway), (fluorescent proteins, other yeasts of Yarrowia clade), (carotenoid pathway, other yeasts of Yarrowia clade)
# Progress: 10.99% completed
# Response for Row 11:
# Answer to Question 2: (multiple nonrepetitive coding sequence calculator, optimal copy number combination), (machine learning method, optimal copy number combination), (optimal copy number combination, performance), (optimal copy number combination, species Yarrowia lipolytica), (optimal copy number combination, species Escherichia coli), (optimal copy number combination, species Saccharomyces cerevisiae), (coding DNA sequence variants, performance), (coding DNA sequence variants, species Yarrowia lipolytica), (coding DNA sequence variants, species Escherichia coli), (coding DNA sequence variants, species Saccharomyces cerevisiae), (performance, species Yarrowia lipolytica), (performance, species Escherichia coli), (performance, species Saccharomyces cerevisiae), (species Yarrowia lipolytica, eicosapentaenoic acid biosynthesis), (species Escherichia coli, lycopene production), (genetic stability, performance), (genetic stability, species Yarrowia lipolytica), (genetic stability, species Escherichia coli), (genetic stability, species Saccharomyces cerevisiae)
# Progress: 12.09% completed
# Response for Row 12:
# Answer to Question 2: (genes, astaxanthin), (genes, Haematococcus pluvialis), (genes, Xanthophyllomyces dendrorhous), (genes, Escherichia coli), (genes, Saccharomyces cerevisiae), (genes, Yarrowia lipolytica), (astaxanthin synthesis, metabolic flow), (astaxanthin, Haematococcus pluvialis), (astaxanthin, Xanthophyllomyces dendrorhous), (astaxanthin, Escherichia coli), (astaxanthin, Saccharomyces cerevisiae), (astaxanthin, Yarrowia lipolytica), (microbial hosts, astaxanthin synthesis), (extraction methods, efficiency), (superfluid extraction, astaxanthin), (ionic liquid extraction, astaxanthin), (microwave-assisted extraction, astaxanthin)
# Progress: 13.19% completed
# Response for Row 13:
# Answer to Question 2: (cell biomass, astaxanthin production), (cell biomass, gene expression), (astaxanthin production, gene expression), (lipid metabolism, carbon flux), (acetyl-CoA, carbon flux), (mevalonate supply, carbon flux), (central carbon metabolism, carbon flux), (ATP-binding cassette transporter, cofactors), (thiamine pyrophosphate, cofactors), (carotenoid hydroxylase, cofactors), (cell membrane stress, astaxanthin production), (balancing cell growth, astaxanthin production)
# Progress: 14.29% completed
# Response for Row 14:
# Answer to Question 2: (bioprocess conditions, performance), (β-carotene 15,15'-dioxygenase, retinal), (β-carotene 15,15'-dioxygenase, retinol), (β-carotene, retinal), (β-carotene, retinol), (retinal, retinol), (Tween 80, extraction efficiency), (butylated hydroxytoluene, oxidation prevention), (enzymes converting retinal to retinol, extracellular retinol), (extracellular retinol, performance), (intracellular retinol, performance), (species Yarrowia lipolytica, bioprocess conditions), (species Yarrowia lipolytica, enzymes), (bioprocess conditions, intracellular retinol), (enzymes converting retinal to retinol, intracellular retinol)
# Progress: 15.38% completed
# Response for Row 15:
# Answer to Question 2: (ABA yield, <i>IDI</i>), (ABA yield, <i>ERG12S</i>), (ABA yield, <i>ERG20Y<sub>MT</sub></i>), (ABA yield, <i>bcaba3</i>), (ABA yield, <i>bcaba1</i>), (<i>IDI</i>, ABA yield), (<i>IDM</i>, ABA yield), (<i>ERG12S</i>, ABA yield), (<i>ERG20Y<sub>MT</sub></i>, ABA yield), (<i>bcaba3</i>, ABA yield), (<i>bcaba1</i>, ABA yield), (ABA yield, <i>bccpr1</i>), (<i>bccpr1</i>, ABA yield), (mevalonate, mitochondria HMG-CoA synthase), (acetyl-CoA, mevalonate), (mitochondria acetyl-CoA conversion to mevalonate, increase in ABA yield), (HMG-CoA reductase, increase in ABA yield), (HMG-CoA synthase in mitochondria location, increase in ABA yield), (mevalonate, increase in ABA yield), (dodecane addition, fed-batch fermentation ABA production), (fed-batch fermentation process with dodecane addition, highest ABA yield)
# Progress: 16.48% completed
# Response for Row 16:
# Answer to Question 2: (enhancing MVA pathway, α-carotene), (α-carotene synthase OluLCY, subcellular organelles), (subcellular organelles, α-carotene production), (hydroxylase activity, N-terminal transport peptide), (N-terminal transport peptide, hydroxylases location), (hydroxylases location, lutein production), (lutein production, antioxidant 2,6-ditert-butyl-4-methylphenol), (antioxidant 2,6-ditert-butyl-4-methylphenol, lutein yield), (Yarrowia lipolytica, α-carotene production), (Yarrowia lipolytica, hydroxylase activity), (Yarrowia lipolytica, lutein production)
# Progress: 17.58% completed
# Response for Row 17:
# Answer to Question 2: (acetic acid concentration, lipid profiles), (acetic acid concentration, β-carotene production), (acetic acid consumption, lipid profiles), (acetic acid consumption, β-carotene production), (lipid profiles, Yarrowia lipolytica), (β-carotene production, Yarrowia lipolytica), (acetic acid, lipid profiles), (acetic acid, β-carotene production), (growth conditions, acetic acid concentration)
# Progress: 18.68% completed
# Response for Row 18:
# Answer to Question 2: (genes, performance), (genes, species Yarrowia lipolytica), (genes, nutrient conditions), (performance, species Yarrowia lipolytica), (performance, nutrient conditions), (species Yarrowia lipolytica, nutrient conditions), (enzyme expression, performance), (enzyme expression, species Yarrowia lipolytica), (enzyme expression, nutrient conditions), (lipids production, bioprocess conditions), (lipids production, pH effects), (β-carotene production, bioprocess conditions), (β-carotene production, pH effects), (acetic acid tolerance, performance), (acetic acid tolerance, species Yarrowia lipolytica), (pH effects, lipid content), (pH effects, β-carotene concentration), (nutrient conditions, acetic acid tolerance), (nutrient conditions, lipid profiles), (bioprocess conditions, enzyme expression), (biocatalysts, bioprocessing), (syngas, biocatalysts), (polluting byproducts, syngas)
# Progress: 19.78% completed
# Response for Row 19:
# Answer to Question 2: (bioprocess conditions, β-carotene concentration), (bioprocess conditions, mevalonate), (bioprocess conditions, gene mvaE), (bioprocess conditions, gene mvaS<sub>MT</sub>), (bioprocess conditions, enzyme comparison), (bioprocess conditions, modular assembly), (gene mvaE, β-carotene concentration), (gene mvaS<sub>MT</sub>, β-carotene concentration), (enzyme comparison, β-carotene concentration), (modular assembly, β-carotene concentration), (β-carotene concentration, mevalonate), (mevalonate, β-carotene concentration), (wild and mutant enzyme comparison, β-carotene concentration), (crtZ gene, α-carotene concentration), (crtZ gene, zeaxanthin production), (RFNR1 oxidoreductase, zeaxanthin production), (CrtZ, zeaxanthin production), (zeaxanthin production, bioprocess conditions)
# Progress: 20.88% completed
# Response for Row 20:
# Answer to Question 2: (CRISPR-iCas9, genetic modification), (CRISPR-iCas9, efficiency), (CRISPR-iCas9, time of genetic modification), (CRISPR-iCas9, knockout efficiency), (CRISPR-iCas9, nonsense suppressors), (CRISPR-iCar9, gene integration), (gene integration, key genes), (key genes, carotene), (iCas9 mutants, efficiency), (efficiency, Yarrowia lipolytica), (Y. lipolytica, knockout efficiency), (Y. lipolytica, genetic modification time), (optimal target disruption, knockout efficiency), (single gene-guided version, knockout efficiency), (multiple genes, simultaneous knockout efficiency), (fragment integration, chromosome), (fragments, dry cell weight), (carotenoid bioproduction, Y. lipolytica)
# Progress: 21.98% completed
# Response for Row 21:
# Answer to Question 2: (genes Mhy1, species Yarrowia lipolytica), (genes Mhy1, morphology), (morphology, species Yarrowia lipolytica), (gene Cla4, species Yarrowia lipolytica), (gene Cla4, morphology), (genetic engineering pathway genes CarRA, gene CarB), (species Blakeslea trispora, gene CarB), (species Blakeslea trispora, gene CarRA), (gene GGS1, β-carotene yield), (tHMG1 gene overexpression, β-carotene yield), (transporter engineering YTH1, fermentation delays), (transporter engineering YTH3, fermentation delays), (fermentation delay, increased β-carotene accumulation), (species Y. lipolytica, erythritol production rate), (erythritol production values, glucose levels), (β-carotene yield, DCW), (production performance, bioprocess conditions), (bioprocess conditions, morphology), (morphology, β-carotene synthesis pathway genes), (performance, species Yarrowia lipolytica)
# Progress: 23.08% completed
# Response for Row 22:
# Answer to Question 2: (plant hormone, growth), (abscisic acid, drought resistance), (abscisic acid, salt tolerance), (abscisic acid, fruit browning), (abscisic acid, malaria incidence rate), (abscisic acid, insulin secretion), (abscisic acid, agriculture application), (abscisic acid, medicine application), (abscisic acid, plant extraction), (abscisic acid, chemical synthesis), (abscisic acid, microorganism synthesis), (microorganisms, economic production route), (microorganisms, sustainable production route), (Botrytis cinerea, abscisic acid synthesis), (Cercospora rosea, abscisic acid synthesis), (Saccharomyces cerevisiae, heterologous expression), (Yarrowia lipolytica, heterologous expression), (Escherichia coli, heterologous expression), (chassis cells, key enzyme screening), (chassis cells, cofactor regulation), (chassis cells, precursor supply enhancement), (chassis cells, efflux promotion)
# Progress: 24.18% completed
# Response for Row 23:
# Answer to Question 2: (copper, OsTIR1), (copper, NAA-dependent GFP degradation), (NAA, GFP degradation), (NAA, OsTIR1 activation), (GFP degredation, mIAA7), (OsTIR1, GFP degradation), (mIAA7, GFP stability), (mIAA7, protein knockdown efficiency), (F74A mutant, reduced leaky degradation), (5-Ad-IAA, efficient GFP degradation), (5-Ad-IAA, OsTIR1 activation), (Western blot analysis, degron cleavage detection), (mIAA7, metabolic enzyme activity reduction), (OsTIR1<sup>F74A</sup>, controlled protein knockdown), (β-carotene ketolase, canthaxanthin production), (control culture conditions, canthaxanthin levels), (culture inoculation timing, degradation efficacy), (5-Ad-IAA addition time, canthaxanthin reduction)
# Progress: 25.27% completed
# Response for Row 24:
# Answer to Question 2: (genes crtI, beta-carotene), (genes crtE, beta-carotene), (genes crtYB, beta-carotene), (engineered strain Yli-C, beta-carotene titer), (mevalonate pathway gene expression, beta-carotene titer), (fatty acid synthesis pathway enhancement, beta-carotene titer), (strains Yli-CAH, modified biosynthesis rate), (enzyme tHMGR, beta-carotene production), (beta-carotene synthesis related genes copy number increase, beta-carotene production), (strain Yli-C2AH2, optimized fermentation conditions), (optimized fermentation conditions, beta-carotene titer), (engineered strain performance, gene expression), (species Yarrowia lipolytica, beta-carotene production pathway enhancement)
# Progress: 26.37% completed
# Response for Row 25:
# Answer to Question 2: (plant oils, value-added products), (animal fats, value-added products), (triacylglycerol, lipid substrates), (Yeasts, biomanufacturing feedstocks), (Yarrowia lipolytica, microbial platform), (Yarrowia lipolytica, efficient catabolism), (Yarrowia lipolytica, bioconversion of lipid substrates), (fatty acid transport, metabolic engineering strategies), (fatty acid catabolism, metabolic engineering strategies), (redox balances, energy yield), (cell morphology, stress response), (bioreaction engineering, product synthesis opportunities), (long-chain diacids, unique synthesis from oils and fats), (wax esters, unique synthesis from oils and fats), (terpenes, unique synthesis from oils and fats), (carotenoids, unique synthesis from oils and fats)
# Progress: 27.47% completed
# Response for Row 26:
# Answer to Question 2: (protein engineering, β-carotene), (protein engineering, species), (promoters engineering, β-carotene), (promoters engineering, species), (morphological engineering, β-carotene), (morphological engineering, species), (species, β-carotene)
# Progress: 28.57% completed
# Response for Row 27:
# Answer to Question 2: (glycosylation, water solubility), (glycosylation, bioavailability), (glycosylation, photostability), (glycosylation, biological activities), (carotenoid 4-hydroxy-β-ring 4-dehydrogenase (HBFD), astaxanthin production), (carotenoid β-ring 4-dehydrogenase (CBFD), astaxanthin production), (modularized assembly of CBFD and HBFD, astaxanthin production yield), (replacement of the promoter upstream CBFD, astaxanthin production yield), (increasing precursor β-carotene supply, astaxanthin production yield), (regulation of expressions of CBFD and HBFD, astaxanthin production yield), (<i>crtX</i>, glycosylated astaxanthin production), (glycosylated astaxanthin production, microbially produced yield)
# Progress: 29.67% completed
# Response for Row 28:
# Answer to Question 2: (bioprocess conditions, performance), (bioprocess conditions, species B), (bioprocess conditions, species Yarrowia lipolytica), (bioprocess conditions, species Pseudomonas putida), (gene expression, protein overexpression), (protein overexpression tests, metabolite analysis), (encapsulation mechanism, growth interference prevention), (growth interference prevention, sucrose concentrations increase), (sucrose concentrations increase, indigoidine production), (indigoidine production, titer yield improvement), (titer yield improvement, bioprocess conditions optimization), (hydrogel encapsulation, microenvironment favorability), (microenvironment favorability, cell metabolism similarity), (cell metabolism similarity, performance enhancement), (performance enhancement, product recovery ease), (product recovery ease, cyanobacterial reuse), (cyanobacterial reuse, batch cycle efficiency), (bioreactor culture, sucrose production increase), (sucrose production increase, indigoidine titer yield), (indigoidine titer yield, β-carotene titer yield), (β-carotene titer yield, encapsulation effectiveness)
# Progress: 30.77% completed
# Response for Row 29:
# Answer to Question 2: (gene expression, performance), (gene expression, species Yarrowia lipolytica), (species Yarrowia lipolytica, bioproduction ability), (new enzymes, biotechnological importance), (substrate utilization, recombinant protein production), (recombinant protein production, metabolic events), (metabolic events, substrate utilization), (bioprocess conditions, gene expression), (gene expression, performance), (species Yarrowia lipolytica, feed), (feed, disease control), (disease control, food industry), (food waste, single-cell protein), (single-cell protein, species Yarrowia lipolytica)
# Progress: 31.87% completed
# Response for Row 30:
# Answer to Question 2: (genes, β-carotene), (genes, lipid metabolism), (genes, sterol metabolism), (genes, signal transduction), (genes, stress response), (gene disruption, fatty acid oxidation), (gene disruption, lipid composition), (gene disruption, sterol transcriptional regulation), (4CL-8, β-carotene), (GCS, β-carotene), (YIsterTF, β-carotene), (gene disruption, β-carotene production), (lipid metabolism, β-carotene), (sterol metabolism, lipid composition), (sterol metabolism, β-carotene), (signal transduction, β-carotene), (stress response, sterol transcriptional regulation), (fatty acid oxidation, lipid composition), (high-throughput screening, gene disruption), (mutagenesis libraries, gene targets), (fluorescence-activated cell-sorting approach, high-throughput screening), (mutation rates, genetic engineering efficiency)
# Progress: 32.97% completed
# Response for Row 31:
# Answer to Question 2: (β-carotene ketolase CrtW, astaxanthin biosynthesis), (β-carotene hydroxylase CrtZ, astaxanthin biosynthesis), (PspCrtW, biomass), (HpCrtZ, biomass), (PspCrtW, biomass and astaxanthin biosynthesis), (HpCrtZ, biomass and astaxanthin biosynthesis), (expression of enzymes, biomass and astaxanthin biosynthesis), (uracil/leucine biosynthesis, biomass and astaxanthin biosynthesis), (pathway modification, cell metabolism), (transcriptome information, cell metabolism), (cell metabolism, astaxanthin biosynthesis), (strain DN30, astaxanthin synthesis), (5-L fermenter conditions, strain DN30 performance)
# Progress: 34.07% completed
# Response for Row 32:
# Answer to Question 2: (RAS2, hyphal formation), (hyphal formation, biosynthetic activity), (hyphal formation, oxygen mass transfer), (hyphal formation, nutrient mass transfer), (hyphal formation, culture viscosity), (RAS2, performance), (RAS2, lycopene production), (lycopene production, performance), (bioprocess conditions, RAS2), (RAS2, lycopene yield), (glycerol, metabolic activity)
# Progress: 35.16% completed
# Response for Row 33:
# Answer to Question 2: (genes, performance), (genes, species), (gene A, gene B), (genes, bioprocess conditions), (gene A, species), (gene B, species), (gene C, species), (carotenoid pathway genes, β-carotene production), (cloning and expression system, performance), (multigene expression vectors, transformation efficiency), (Golden Gate cloning strategy, transformation into Y. lipolytica), (Golden Gate cloning, gene expression), (heterologous expression, carotenoid synthesis), (gene A, growth conditions), (gene B, growth conditions), (gene C, growth conditions), (cloning system, β-carotene production)
# Progress: 36.26% completed
# Response for Row 34:
# Answer to Question 2: (BCO gene, retinal), (RDH, retinol), (GGS1<sup>F43I</sup>, β-carotene), (FAD1, carotenoid production), (deletion of genes, carotenoid production), (Mb.Blh, retinol), (Mb.Blh, β-carotene level), (BHT, retinol production), (GSH2, retinol production), (Raman imaging, lipid droplets localization), (Tween 80, retinol extraction), (retinal degradation, oxidative damage), (lipid droplets, retinol localization), (Y. lipolytica, β-carotene overproducer), (Y. lipolytica, retinol producer), (fermentation conditions, retinol production)
# Progress: 37.36% completed
# Response for Row 35:
# Answer to Question 2: (CRISPR-based gene expression toolkit, performance), (CRISPR-based gene expression toolkit, species Yarrowia lipolytica), (integration sites, high expression), (genetic components, gene expression), (new terminators, gene expression), (promoters, gene expression), (gene regulation, lycopene production), (lycopene biosynthesis pathway, lycopene production), (species Yarrowia lipolytica, performance)
# Progress: 38.46% completed
# Response for Row 36:
# Answer to Question 2: (gene deletions, production capability), (gene deletions, yeast growth rate), (gene deletions, chromosomes usage), (production capability, β-carotene), (production capability, succinic acid), (β-carotene, Yarrowia lipolytica), (succinic acid, Saccharomyces cerevisiae), (GPH1 gene knockout, enzyme activation), (GPH1 gene knockout, isocitrate lyase activity), (isocitrate lyase enzyme, isocitrate to succinate conversion), (constraints, essential genes), (knockout genes, genetic engineering process), (chromosomes usage, yeast growth rate), (production capability, metabolic constraints), (genetic engineering process, microorganisms efficiency), (multiobjective optimization, strains production), (bioprocess conditions, performance), (in silico simulations, ranking of strains)
# Progress: 39.56% completed
# Response for Row 37:
# Answer to Question 2: (genes, ABA production), (genes, strain improvement), (Yarrowia lipolytica, ABA production), (mevalonate flux, ABA titer), (BcABA1 gene expression, ABA titer), (additional gene copies, ABA titer), (mevalonate pathway integration, ABA yield), (ABA biosynthesis genes, ABA yield), (plant ABA transporters, ABA production), (bioreactor cultivation, biomass level), (bioreactor cultivation, ABA titer), (performance, strain improvement)
# Progress: 40.66% completed
# Response for Row 38:
# Answer to Question 2: (gene expression, yield), (gene expression, cost of cultivation), (gene expression, extraction), (metabolic engineering, yield), (metabolic engineering, cost of cultivation), (metabolic engineering, extraction), (non-native microbial cell factories, yield), (non-native microbial cell factories, cost of cultivation), (non-native microbial cell factories, extraction), (astaxanthin biosynthetic pathways, regulation), (transcriptional regulations, lipid metabolism), (lipid metabolism, astaxanthin production), (fermentation process control, yield), (fermentation process control, cost of cultivation), (fermentation process control, extraction)
# Progress: 41.76% completed
# Response for Row 39:
# Answer to Question 2: (β-carotene ketolases CrtW, astaxanthin), (β-carotene hydroxylases CrtZ, astaxanthin), (HpCrtW and HpCrtZ transcriptional expression, biomass), (gene integration into genome, biomass), (leucine biosynthesis, biomass), (biomass, performance), (astaxanthin production, performance), (fed-batch conditions, astaxanthin production), (Yarrowia lipolytica, biomass), (Yarrowia lipolytica, performance)
# Progress: 42.86% completed
# Response for Row 40:
# Answer to Question 2: (substrate inhibition, enzymatic activity), (substrate inhibition, carotenoid biosynthesis), (protein engineering, substrate inhibition), (protein engineering, enzymatic activity), (Y27R variant, substrate inhibition), (Y27R variant, enzymatic activity), (geranylgeranyl pyrophosphate synthase-mediated flux flow, metabolic flux), (metabolic flux, substrate inhibition), (metabolic flux, inhibitory metabolite), (inhibitory metabolite, substrate inhibition), (product formation, substrate inhibition), (β-carotene production, strain), (strain, productivity), (bioreactor fermentations, productivity), (initial strain, productivity), (substrate inhibition, carotenoid biosynthesis efficiency), (enzymes, bioprocess conditions), (enzyme activity, species Yarrowia lipolytica), (metabolic flux, species Yarrowia lipolytica)
# Progress: 43.96% completed
# Response for Row 41:
# Answer to Question 2: (casual mutations, genetic analysis), (NHEJ-mediated integration, genome-scale trackable mutagenesis library), (NHEJ-mediated integration, chromosomes), (transcriptional regulatory regions, integration preference), (insertions, nucleosome-occupancy regions), (insertions, nucleosome-free regions), (β-carotene biosynthesis, improved performance), (acetic acid tolerance, improved performance), (genome-scale mutagenesis library, cell factory construction), (cell factory construction, organisms with strong NHEJ preference)
# Progress: 45.05% completed
# Response for Row 42:
# Answer to Question 2: (beta-carotene, performance), (beta-carotene, species Yarrowia lipolytica), (species Yarrowia lipolytica, gene CLA4), (gene CLA4, mycelium form), (mycelium form, performance), (genetic engineering of CLA4 deletion, yeast form recovery), (yeast form recovery, performance), (beta-carotene content increase, morphological transition), (morphological transition, metabolic stress), (metabolic stress relief, improved β-carotene production), (gene MYH1, mycelium form), (mycelium to yeast form conversion, increased β-carotene production), (bioprocess conditions, gene expression), (genetic engineering method, performance)
# Progress: 46.15% completed
# Response for Row 43:
# Answer to Question 2: (crtZ, zeaxanthin), (crtZ, performance), (crtZ, Yarrowia lipolytica), (Eu-crtZ, zeaxanthin titer), (Eu-crtZ, zeaxanthin content), (Eu-crtZ, dry cell weight), (high-copy-number integration, zeaxanthin titer), (high-copy-number integration, zeaxanthin content), (YPD medium, zeaxanthin production), (YNB medium, zeaxanthin content), (citric acid, citric acid detection), (Yarrowia lipolytica, lycopene accumulation), (Yarrowia lipolytica, β-carotene accumulation)
# Progress: 47.25% completed
# Response for Row 44:
# Answer to Question 2: (enzymes, astaxanthin synthesis), (enzymes, lipid body), (enzymes, endoplasmic reticulum), (enzymes, peroxisome), (astaxanthin biosynthesis pathway, subcellular organelles), (subcellular organelles, astaxanthin synthesis), (β-carotene ketolase and hydroxylase fusion, performance), (enzyme expression in lipid body, astaxanthin production), (enzyme expression in endoplasmic reticulum, astaxanthin production), (enzyme expression in peroxisome, astaxanthin production), (lipid body, astaxyanthin conversion), (endoplasmic reticulum, astaxyanthin conversion), (peroxisome, astaxyanthin conversion), (enzymes in lipid body and endoplasmic reticulum, astaxanthin synthesis), (enzymes in endoplasmic reticulum and peroxisome, astaxanthin synthesis), (enzymes in lipid body and peroxisome, astaxanthin synthesis), (all three organelles targeting enzymes, increased astaxanthin production), (gene expression strategy, gene performance), (subcellular compartmentalization, metabolic cross-talk prevention), (compartmentalized pathways, efficient synthesis of compounds), (growth conditions, enzyme anchoring in organelles), (organellar targeting, enzymatic efficiency), (enzymes fusion, β-carotene conversion to astaxanthin), (gene expression strategy, lipid body use), (gene expression strategy, endoplasmic reticulum use), (gene expression strategy, peroxisome use)
# Progress: 48.35% completed
# Response for Row 45:
# Answer to Question 2: (DID2 gene, β-carotene), (DID2 gene, biomass), (DID2 gene, mRNA level), (DID2 gene, protein level), (DID2 gene, FPP), (DID2 gene, Lycopene), (DID2 gene, glucose pathway genes), (DID2 gene, pentose phosphate pathway genes), (DID2 gene, tricarboxylic acid cycle genes), (β-carotene synthesis pathway genes, mRNA level), (FPP, β-carotene), (Lycopene, β-carotene), (glucose utilization, cofactors consumption), (cofactors consumption, glucose utilization), (DID2 gene, glucose utilization), (DID2 gene, cofactors consumption), (β-carotene production, biomass), (biomass, β-carotene production)
# Progress: 49.45% completed
# Response for Row 46:
# Answer to Question 2: (gene expression, performance), (gene expression, species), (gene expression, bioprocess conditions), (bioprocess conditions, gene expression), (bioprocess conditions, performance), (species, gene expression), (species, performance)
# Progress: 50.55% completed
# Response for Row 47:
# Answer to Question 2: (oleaginous yeasts, carotenoid production), (Yarrowia lipolytica, lipid synthesis), (Lipomyces starkeyi, lipid synthesis), (lipid synthesis, industrial biodiesel fuel production), (carotenoids, value-added lipophilic compound production), (Rhodotorula glutinis, natural carotenoids production), (Xanthophyllomyces dendrorhous, natural carotenoids production), (Lipomytes starkeyi, lycopene production), (pathway engineering, lycopene production)
# Progress: 51.65% completed
# Response for Row 48:
# Answer to Question 2: (codon-adapted genes, β-carotene production), (codon-adapted genes, metabolic balance), (β-carotene biosynthetic pathway's metabolic balance, intermediates' accumulation), (HMG-CoA and FPP accumulation, β-carotene content), (expression levels of CarRA and CarB genes, phytoene and lycopene accumulation), (metabolic balance, β-carotene production), (rate-limiting enzymes CarRA and CarB, catalytic activity), (minimizing intermediate accumulation, β-carotene production), (Yarrowia lipolytica, codon-adapted genes integration), (β-carotene content, dry cell weight), (enzymes CarRA and CarB, intermediates' reduction), (bioprocess conditions, gene expression levels), (β-carotene-producing strain, industrial production)
# Progress: 52.75% completed
# Response for Row 49:
# Answer to Question 2: (NHEJ, genes integration efficiency), (NHEJ, genomic library construction), (NHEJ, desirable phenotypic traits), (NHEJ repair process regulation, genes integration efficiency), (defective Ura marker use, genes integration efficiency), (iterative transformations optimization, genes integration efficiency), (heterologous gene CrtE multi-integration, lycopene production), (heterologous gene CrtB multi-integration, lycopene production), (heterologous gene CrtI multi-integration, lycopene production), (HR rDNA integration, lycopene production), (NHEJ-mediated genomic library technology, random and scattered genomic integration), (loxP and vox sites random integration, genome rearrangement potential), (gene CrtE, lycopene production), (gene CrtB, lycopene production), (gene CrtI, lycopene production), (Yarrowia lipolytica genomic modifications, phenotypes superior performance), (NHEJ-mediated technology, rapid diverse strains generation)
# Progress: 53.85% completed
# Response for Row 50:
# Answer to Question 2: (CRISPR/Cas9, targeted genome integration), (CRISPR/Cas9, cleavage efficiency of Cas9), (cleavage efficiency of Cas9, targeted integration rate), (manipulation of NHEJ repair, targeted integration rate), (cell cycle synchronization, targeted integration rate), (integration sites, targeted integration rate), (G1 phase synchronization, targeted integration rate), (intronic promoters, rapid verification), (multiple genes, iterative integration), (canthaxanthin biosynthesis pathway, iterative integration), (genome-editing methods, performance), (homolopy-independent method, genome editing methods), (Yarrowia lipolytica, CRISPR/Cas9), (Yarrowia lipolytica, targeted genome integration tool), (Yarrowia lipolytica, homologous recombination), (homology-independent integration tool, Y. lipolytica), (DNA fragment, one-step integration), (gene expression verification, rapid process), (genome-editing methods, bioprocess efficiency)
# Progress: 54.95% completed
# Response for Row 51:
# Answer to Question 2: (lipases, β-carotene biosynthesis), (lipases, Saccharomyces cerevisiae), (lipases, growth conditions), (β-carotene biosynthetic pathway genes, β-carotene), (β-carotene biosynthetic pathway genes, Saccharomyces cerevisiae), (β-carotene, lipases), (hydrophobic substrate supplementation, lipases expression), (hydrophobic substrate supplementation, β-carotene production), (growth conditions, β-carotene), (growth conditions, Saccharomyces cerevisiae), (lipase LIP2, olive oil growth), (lipase LIP7, olive oil growth), (lipase LIP8, olive oil growth), (crtI gene, β-carotene production), (crtYB gene, β-carotene production), (crtE gene, β-carotene production), (olive oil supplementation, lipases expression), (olive oil supplementation, increased lipid content), (lipid content, olive oil growth conditions)
# Progress: 56.04% completed
# Response for Row 52:
# Answer to Question 2: (DO-stat fed-batch fermentation, biomass), (DO-stat fed-batch fermentation, β-carotene), (DO-stat fed-batch fermentation, ATP), (DO-stat fed-batch fermentation, NADP<sup>+</sup>/NADPH), (DO-stat fed-batch fermentation, tHMG gene expression levels), (DO-stat fed-batch fermentation, GGS1 gene expression levels), (DO-stat fed-batch fermentation, carRA gene expression levels), (DO-stat fed-batch fermentation, carB gene expression levels), (biomass, β-carotene), (ATP, NADP<sup>+</sup>/NADPH), (tHMG gene expression levels, GGS1 gene expression levels), (tHMG gene expression levels, carRA gene expression levels), (tHMG gene expression levels, carB gene expression levels), (GGS1 gene expression levels, carRA gene expression levels), (GGS1 gene expression levels, carB gene expression levels), (carRA gene expression levels, carB gene expression levels), (DO-stat fed-batch fermentation, μ<sub>m</sub>'), (DO-stat fed-batch fermentation, Y<sub>x/s</sub>'), (DO-stat fed-batch fermentation, Y<sub>p/s</sub>'), (μ<sub>m</sub>', biomass), (Y<sub>x/s</sub>', biomass), (Y<sub>x/s</sub>', β-carotene), (Y<sub>p/s</sub>', β-carotene)
# Progress: 57.14% completed
# Response for Row 53:
# Answer to Question 2: (genes, performance), (genes, species Yarrowia lipolytica), (species Yarrowia lipolytica, performance), (Perilla frutescens limonene synthase, performance), (Perilla frutescens limonene synthase, species Yarrowia lipolytica), (mevalonate pathway improvement, gene expression), (mevalonate pathway improvement, performance), (Callitropsis nootkatensis valencene synthase, performance), (Callitropsis nootkatensis valencene synthase, species Yarrowia lipolytica), (squalene production, genes), (squalene production, performance), (2,3-oxidosqualene production, genes), (2,3-oxidosqualene production, performance), (β-carotene production, genes), (β-carotene production, performance)
# Progress: 58.24% completed
# Response for Row 54:
# Answer to Question 2: (CRISPR/Cas9-mediated method, disruption efficiency), (sgRNAs combinations, URA3 gene), (URA3 gene, coding sequence), (coding sequence, auxotrophic mutants), (auxotrophic mutants, cloning rates), (fluorescent phenotype, engineered strains), (β-carotene synthesis, carotenoid-producing strains), (carotenoid-producing strains, growth profile), (growth profile, wild-type strain), (ura3Δ strains, β-carotene), (YPD culture conditions, β-carotene production), (YNB culture conditions, β-carotype production), (Yarrowia lipolytica IMUFRJ 50682, genomic information), (genomic information, auxotrophic mutants), (growth profile, β-carotene synthesis)
# Progress: 59.34% completed
# Response for Row 55:
# Answer to Question 2: (Hxk gene, hexokinase activity), (Hxk gene, glucose-6-phosphate content), (Hxk gene, transcriptional level of Hxk), (Hxk gene, β-carotene content), (glucose consumption rate, Hxk gene), (erg13 gene, 3-Hydroxy-3-Methylglutaryl-CoA content), (erg13 gene, β-carotene content), (hexokinase activity, glucose utilization rate), (glucose-6-phosphate content, β-carotene production), (transcriptional level of Hxk, β-carotene content), (hydroxymethylglutaryl-CoA synthase, precursor supply for β-carotene biosynthesis), (erg13 gene, hexokinase activity), (erg13 gene, glucose utilization rate), (bioprocess conditions, fermentation cycle time), (bioprocess conditions, β-carotene titer), (hexokinase activity, 3-Hydroxy-3-Methylglutaryl-CoA content), (precursor supply for β-carotene biosynthesis, β-carotene production), (fermentation cycle time, β-carotene titer)
# Progress: 60.44% completed
# Response for Row 56:
# Answer to Question 2: (bioprocess conditions, cell growth), (bioprocess conditions, astaxanthin production), (cell growth, astaxanthin production), (safflower oil, cell growth), (safflower oil, astaxanthin production), (engineered Yarrowia lipolytica strain ST7403, cell growth), (engineered Yarrowia lipolytica strain ST7403, astaxanthin production), (astaxanthin, extracellular oil phase), (astaxanthin, excretion into spent oil), (peroxide level, decline during fermentation), (bioprocess conditions, peroxide level), (autoclaving safflower oil medium, peroxide level increase), (fermentation, cell growth), (fermentation, astaxanthin production), (carbon-to-nitrogen ratio yeast extract/peptone medium, astaxanthin titer productivity improvement), (additional yeast extract/peptone feeding, astaxanthin titer productivity improvement)
# Progress: 61.54% completed
# Response for Row 57:
# Answer to Question 2: (biomass yields, oil-feedstock), (biomass yields, species B), (oil-feedstock, cell sizes), (oil-feedstock, protein content), (protein content, species B), (enzyme abundances, growth conditions), (glycolysis, TCA cycle), (sugars, fatty acid substrates), (catabolite repressions, resource allocations), (growth mediums, performance), (growth mediums, species B), (canola oil-containing yeast-peptone, β-carotene titer), (β-carotene titer, glucose based YP medium)
# Progress: 62.64% completed
# Response for Row 58:
# Answer to Question 2: (bioprocess conditions, gene expression), (bioprocess conditions, performance), (bioprocess conditions, species Yarrowia lipolytica), (gene expression, performance), (gene expression, species Yarrowia lipolytica), (performance, species Yarrowia lipolytica)
# Progress: 63.74% completed
# Response for Row 59:
# Answer to Question 2: (carotenogenic genes, performance), (carotenogenic genes, Yarrowia lipolytica), (Yarrowia lipolytica, performance), (MVA pathway flux, β-ionone titer), (MVA pathway flux, performance), (modular engineering strategy, β-ionone titer), (modular engineering strategy, performance), (heterologous and native genes, Yarrowia lipolytica), (heterologous and native genes, performance), (fermentation condition, performance), (Yarrowia lipolytica, β-ionone titer)
# Progress: 64.84% completed
# Response for Row 60:
# Answer to Question 2: (carB, β-carotene), (carRP, β-carotene), (GGS1, β-carotene), (ERG13, β-carotene), (HMG, β-carotene), (CRISPR/Cas9, β-carotene production), (CRISPR/Cas9, carB overexpression), (CRISPR/Cas9, carRP overexpression), (CRISPR/Cas9, GGS1 overexpression), (CRISPR/Cas9, ERG13 overexpression), (CRISPR/Cas9, HMG overexpression), (fermenter cultivation, β-carotene production), (Yarrowia lipolytica XK2, β-carotene production), (Y. lipolytica XK19, β-carotene accumulation), (carB, Yarrowia lipolytica XK2), (carRP, Yarrowia lipolytica XK2), (GGS1, Yarrowia lipolytica XK2), (ERG13, Yarrowia lipolytica XK2), (HMG, Yarrowia lipolytica XK2), (Y. lipolytica XK19, Y. lipolytica XK2), (β-carotene production, bioprocess conditions), (bioprocess conditions, β-carotene accumulation)
# Progress: 65.93% completed
# Response for Row 61:
# Answer to Question 2: (gene expression levels, cell factories), (yeast promoters, gene expression levels), (core promoter regions, gene expression levels), (core promoter regions, artificial sequences), (artificial sequences, enzyme CrtY), (enzyme CrtY, lycopene-carotene compositions), (lycopene-carotene compositions, colony-color spectrum), (upstream sequences, expression levels), (P_EXP1, strong promoter activity), (GPD promoter, strong promoter activity), (base motifs, promoter strength), (artificial core promoters, base motifs), (T-rich elements, promoter strength), (%T, promoter strength), (lower G/C percentage, promoter strength), (champion promoter, lycopene-carotene transformation), (beta-carotene production, 7.4 mg/g DCW), (core promoter region length, flexibility in design)
# Progress: 67.03% completed
# Response for Row 62:
# Answer to Question 2: (species Yarrowia lipolytica, performance), (species Yarrowia lipolytica, bioprocess conditions), (genetic tools, species Yarrowia lipolytica), (metabolic understanding, species Yarrowia lipolytica), (Y. lipolytica, polyketides), (Y. lipolytica, terpenes), (Y. lipolytica, carotenoids), (Y. lipolytica, pentose phosphate-derived products), (Y. lipolytica, polymers), (Y. lipolytica, nanoparticles)
# Progress: 68.13% completed
# Response for Row 63:
# Answer to Question 2: (genes encoding β-ketolase, astaxanthin), (genes encoding β-hydroxylase, astaxanthin), (β-carotene, genes encoding β-ketolase), (β-carotene, genes encoding β-hydroxylase), (platform strain, β-carotene), (Yarrowia lipolytica, platform strain), (gene copy numbers, astaxanthin production), (fermentation, astaxanthin), (bioreactors, fermentation), (growth conditions, astaxanthin production), (gene optimization, performance), (cell factory, Yarrowia lipolytica)
# Progress: 69.23% completed
# Response for Row 64:
# Answer to Question 2: (CRISPR/Cas9, β-carotene production), (CRISPR/Cas9, DNA parts), (EasyClone, β-carotene production), (EasyClone, DNA parts), (metabolic engineering, β-carotene production), (metabolic engineering, yeast), (β-carotene production, yeast), (boosting native precursor supply, β-carotene production), (alleviating rate-limiting steps, β-carotene production), (Saccharomyces cerevisiae, metabolic engineering), (Yarrowia lipolytica, metabolic engineering), (precursor supply, β-carotene production), (rate-limiting steps, β-carotene production), (yeast transformation, DNA parts), (genotyping yeast, β-carotene production), (phenotypic screen, β-carotene production)
# Progress: 70.33% completed
# Response for Row 65:
# Answer to Question 2: (CRISPR-Cas9, editing efficiencies), (CRISPR-Cas9, URA3 gene), (URS3 gene, editing efficiencies), (CAR2 gene, CRISPR-Cas9), (CAR2 gene, editing efficiencies), (gene disruption, CAR2), (genome engineering, performance), (genome engineering, R. toruloides), (R. toruloides, genome engineering), (R. toruloides, production capabilities), (production capabilities, genome engineering)
# Progress: 71.43% completed
# Response for Row 66:
# Answer to Question 2: (species Yarrowia lipolytica, hydrophobic substrates), (species Yarrowia lipolytica, productivity), (species Yarrowia lipolytica, titer), (species Yarrowia lipolytica, rate), (species Yarrowia lipolytica, yield), (hydrophobic substrates, high-value products), (hydrophilic substrates, species Yarrowia lipolytica), (extracellular lipases, biosynthesis), (triacylglycerol oils and fats, conversion), (cell size, cell growth), (cell size, nutrient uptake), (cell size, product formation), (morphology transition, extracellular environments), (morphology transition, genetic background), (YlBEM1, yeast-to-hyphal transition), (YlMHY1, yeast-to-hyphal transition), (YlZNC1, yeast-to-hyphal transition), (cell cycle, cell polarization), (cell polarization, dimorphic transition), (dimorphic transition, growth conditions), (genetic tools, biomanufacturing platform)
# ...
# Progress: 74.73% completed
# Response for Row 69:
# Answer to Question 2: (copy numbers of lycopene synthesis genes, lycopene production), (copy numbers of lycopene synthesis genes, Yarrowia lipolytica), (key central metabolic genes, lycopene production), (AMP deaminase-encoding gene AMPD, lycopene production), (5-L fermenter cultivation, lycopene production), (lycopene content, industrial demand), (genetic engineering methods, lycopene content), (metabolic engineering methods, lycopene content)
# Progress: 75.82% completed
# Response for Row 70:
# Answer to Question 2: (gene expression, performance), (gene copy numbers, gene expression), (chromosomal locations, gene expression), (homology-independent integration, variation), (library construction, high-production strains), (LIP2 expression library, high-production strains), (β-carotene biosynthetic pathway library, high-production strains), (Y. lipolytica, homology-independent genome integration), (variation, performance), (genetic engineering methods, Y. lipolytica), (genome integration, gene copy numbers), (homology-independent integration, gene expression libraries), (gene expression differences, performance)
# Progress: 76.92% completed
# Response for Row 71:
# Answer to Question 2: (β-carotene, performance), (CCD1, β-ionone), (CCD1, performance), (acetyl-CoA supply, β-ionone), (strain stability, performance), (genome engineering, β-carotene), (gene expression, β-carotene), (mevalonate pathway genes, β-carotene), (carB and carRP genes, β-carotene), (Yarrowia lipolytica, β-ionone production), (fermentation conditions, β-ionone loss), (in situ dodecane trapping, ionone recovery efficiency), (machine learning data analysis, nutrient influence), (<sup>13</sup>C metabolite labeling, influential nutrients), (nutrient supply, performance), (β-carotene titer, fermentation outcomes), (Y. lipolytica sub-cultures, performance), (industrial application, CCD enzyme engineering), (industrial application, strain stability improvement)
# Progress: 78.02% completed
# Response for Row 72:
# Answer to Question 2: (genes, performance), (genes, species Yarrowia lipolytica), (species Yarrowia lipolytica, performance), (transcriptional factor Yl-SPT15, genes), (Yl-SPT15 mutants, carotene production), (Yl-SPT15 mutants, lipid production), (combinatorial mutagenesis of Yl-SPT15, lipophilic properties), (carotene biosynthetic pathway, lipophilic properties), (RNA polymerase, lipophilicity), (ketone body metabolism, lipophilicity), (fatty acid synthesis, lipophilicity), (fatty acid degradation, lipophilicity), (lipophilic properties, performance)
# Progress: 79.12% completed
# Response for Row 73:
# Answer to Question 2: (gene ku70, homologous recombination), (gene ku70, non-homologous end-joining), (gene ku70, cell cycle), (homologous recombination, pex10 gene), (homologous recombination, β-carotene biosynthetic genes), (homologous recombination, URA3 marker gene), (cell cycle synchronization, homologous recombination), (hydroxyurea, cell cycle), (S-phase, cell cycle), (hydroxyurea, S-phase), (double-strand break repair, non-homologous end-joining), (homology regions, homologous recombination), (pex10 gene, genetically modified Y. lipolytica strains), (β-carotene biosynthetic genes, genetically modified Y. lipolytica strains), (URA3 marker gene, genetically modified Y. lipolytica strains), (biotechnological applications, genetically modified Y. lipolytica strains), (Yarrowia lipolytica performance, homologous recombination frequency)
# Progress: 80.22% completed
# Response for Row 74:
# Answer to Question 2: (bioprocess conditions, β-carotene), (bioprocess conditions, β-carotene ketolase), (bioprocess conditions, hydroxylase), (β-carotene, astaxanthin), (β-carotene, canthaxanthin), (astaxanthin, species Yarrowia lipolytica), (canthaxanthin, species Yarrowia lipolytica), (crtW, β-carotene ketolase), (crtZ, hydroxylase), (HMG1, β-carotene titer), (GGS1/crtE, β-carotene titer), (SQS1, β-carotene titer), (expression of crtI and crtYB, β-carotene production), (introduction of crtW and crtZ, astaxanthin accumulation), (downregulation of SQS1, increased β-carotene titer), (copy numbers of crtZ and crtW, optimized astaxanthin content)
# Progress: 81.32% completed
# Response for Row 75:
# Answer to Question 2: (mevalonate pathway overexpression, lycopene production), (mevalonate pathway overexpression, host cell physiology), (mevalonate pathway overexpression, metabolism), (auxotrophies alleviation, lycop烯酸钠公式在这里不适用，我将继续按照正确的格式输出所有实体间的因果关系。)
#
# (mevalonate pathway overexpression, performance), (mevalonate pathway overexpression, species Yarrowia lipolytica), (host cell physiology modification, lycopene production), (host cell physiology modification, species Yarrowia lipolytica), (metabolism alteration, lycopene production), (auxotrophies alleviation, lycopene titer), (auxotrophies alleviation, species Yarrowia lipolytica), (leucine biosynthetic capacity recovery, lycopene titer), (leucine biosynthetic capacity recovery, performance), (uracil biosynthetic capacity recovery, lycopene titer), (uracil biosynthetic capacity recovery, performance), (gene overexpression, lycopene production), (gene overexpression, species Yarrowia lipolytica), (genes HMG1, CrtI, MVD1, EGR8, CrtB, and CrtE expression, lycopene titer), (bioprocess conditions, performance)
# Progress: 82.42% completed
# Response for Row 76:
# Answer to Question 2: (β-carotene, performance), (lipid overproducer strain, β-carotene), (wild type, β-carotene), (heterologous pathway, β-carotene production), (promoter-gene pairs, transcriptional units), (transcriptional units, β-carotene production), (synthetic biology approach, heterologous pathway expression), (Golden Gate DNA assembly, promoter-gene pairs screening), (best strain, performance), (glucose consumption, β-carotene yield), (flask culture conditions, β-carotene titer), (fed-batch fermentation, β-carotene production), (β-carotene, lipids production), (Yarrowia lipolytica, β-carotene biosynthesis), (Acetyl-CoA precursor, lipid overproducer strain), (lipid overproducer strain, high Acetyl-CoA levels)
# Progress: 83.52% completed
# Response for Row 77:
# Answer to Question 2: (genetically modified microbes, protein-based products), (protein-based products, antibodies), (protein-based products, enzymes), (microbes, overexpression of multiple enzymes), (microbes, metabolite drainage for product synthesis), (synthetic circuits, heterologous pathways), (hosts' innate regulations, suboptimal fermentation conditions), (engineered enzymes, channeling capabilities), (engineered enzymes, cascade-like transport of metabolites), (genetic mutations, cell-to-cell variations), (cell-to-cell variations, large-scale fermentation outcomes), (synthetic biology strains, unsatisfactory industrial performance), (species exploration, metabolic strengths), (TCA cycle-derived biosynthesis, Corynebacterium glutamicum), (biosynthesis of fatty acids and carotenoids, Yarrowia lipolytica), (photosynthetic production, cyanobacteria), (sugar phosphate pathways, cyanobacteria), (biotransform recalcitrant feedstock, Rhodococcus), (genome-to-phenome mapping, development of novel cell factories), (single cell methods, development of novel cell factories), (knowledge engineering, development of novel cell factories)
# Progress: 84.62% completed
# Response for Row 78:
# Answer to Question 2: (nucleotides, Yarrowia lipolytica), (coenzymes, Yarrowia lipolytica), (capillary electrophoresis, nucleotides), (capillary electrophoresis, coenzymes), (four coenzymes, five nucleotides), (four coenzymes, three nucleosides), (adenosine triphosphate, lycopene production), (nicotinamide adenine dinucleotide phosphate, lycopene production), (metabolic analysis, fermentation process), (industrial strain improvement, metabolic analysis), (Yarrowia lipolytica, adenosine triphosphate), (Yarrowia lipolytica, nicotinamide adenine dinucleotide phosphate)
# Progress: 85.71% completed
# Response for Row 79:
# Answer to Question 2: (crt genes, metabolome profiling), (crt genes, pathway abundance), (crt genes, fructose metabolism), (crt genes, mannose metabolism), (crt genes, citrate cycle), (crt genes, glyoxylate metabolism), (crt genes, dicarboxylate metabolism), (crt genes, glycerophospholipid metabolism), (crt genes, valine biosynthesis), (crt genes, leucine biosynthesis), (crt genes, isoleucine biosynthesis), (metabolome profiling, pathway abundance), (pathway abundance, fructose metabolism), (pathway abundance, mannose metabolism), (pathway abundance, citrate cycle), (pathway abundance, glyoxylate metabolism), (pathway abundance, dicarboxylate metabolism), (pathway abundance, glycerophospholipid metabolism), (pathway abundance, valine biosynthesis), (pathway abundance, leucine biosynthesis), (pathway abundance, isoleucine biosynthesis)
# Progress: 86.81% completed
# Response for Row 80:
# Answer to Question 2: (gene copies, β-carotene), (gene copies, performance), (strong promoters, β-carotene), (strong promoters, performance), (fed-batch fermentation, β-carotene), (fed-batch fermentation, performance), (optimized medium, β-carotene), (optimized medium, performance), (lipid droplets, β-carotene), (lipid droplets, performance), (Y. lipolytica, β-carotene), (Y. lipolytica, performance), (bioprocess conditions, β-carotene), (bioprocess conditions, performance), (12 steps, β-carotene), (12 steps, performance), (high flux of acetyl-CoA, β-carotene), (high flux of acetyl-CoA, performance)
# Progress: 87.91% completed
# Response for Row 81:
# Answer to Question 2: (carS, β-carotene), (carS, Yarrowia lipolytica), (P_GPD promoter, carS), (GGS1, β-carotene), (GGS1, Yarrowia lipolytica), (DNA assembler method, integration efficiency), (ku70, DNA assembler method), (ku80, DNA assembler method), (NHEJ, DNA assembler method), (Y. lipolytica, β-carotene production), (wild type, absence of β-carotene production)
# Progress: 89.01% completed
# Response for Row 82:
# Answer to Question 2: (Golden Gate modular cloning strategy, destination vectors), (Golden Gate modular cloning strategy, interchangeable building blocks), (destination vectors, Yarrowia lipolytica), (interchangeable building blocks, Yarrowia lipolytica), (DNA modules, transcription units), (transcription units, promoter), (transcription units, gene), (transcription units, terminator), (DNA modules, selection marker gene), (selection marker gene, genomic integration targeting sequences), (carotenoid production pathway, destination vectors), (carotenoid production pathway, interchangeable building blocks), (carotenoid production pathway, DNA modules), (construction of DNA modules, regulatory elements), (construction of DNA modules, selection markers), (DNA modular assembly system, performance in Yarrowia lipolytica)
# Progress: 90.11% completed
# Response for Row 83:
# Answer to Question 2: (lipases from Yarrowia lipolytica, free lutein), (lipases from Yarrowia lipolytica, biomass), (biomass, free carotenoids), (Yarrowia lipolytica, growth conditions), (Yarrowia lipolytica, marigold oleoresin), (marigold oleoresin, free carotenoids), (free carotenoids, biomass), (nutrients, Yp/x), (nutrients, Lipases from Yarrowia lipolytica), (hydrolysis efficiency, hydrolysis time), (Yarrowia lipolytica, Rhizopus oryzae), (lipases from Rhizopus oryzae, free carotenoids)
# Progress: 91.21% completed
# Response for Row 84:
# Answer to Question 2: (genes, cell growth), (gene integration, cell growth), (CRISPR-Cas9-based tool, gene integration), (gene integration, genomic loci), (genomic loci, gene expression levels), (gene expression levels, GFP expression cassette), (gene integration, markerless), (markerless gene integration, stable production strains), (gene expression levels, expression consistency), (expression consistency, AXP), (expression consistency, XPR2), (expression consistency, A08), (expression consistency, D17), (expression consistency, MFE1), (genomic loci, standardized tool), (standardized tool, plasmids), (plasmids, gene integration), (gene expression levels, GFP), (GFP expression cassette, gene expression locus), (semisynthetic lycopene biosynthesis pathway, integrated genes), (integrated genes, genomic sites), (genomic sites, known expression levels), (known expression levels, reliable pathway engineering), (reliable pathway engineering, Y. lipolytica)
# Progress: 92.31% completed
# Response for Row 85:
# Answer to Question 2: (genome characteristics, performance), (genome characteristics, species Yarrowia lipolytica), (metabolic engineering, performance), (metabolic engineering, species Yarrowia lipolytica), (internal pathways, performance), (internal pathways, species Yarrowia lipolytica), (new pathways, performance), (new pathways, species Yarrowia lipolytica), (Y. lipolytica, cost-effective production), (Y. lipolytica, fatty acids), (Y. lipolytica, lipids), (Y. lipolytica, acetyl-CoA), (omega-3 eicosapentaenoic acid, commercialization), (omega-3 eicosapentaenoic acid, species Yarrowia lipolytica), (biodiesel fuel, production), (functional fatty acids, production), (carotenoids, production)
# Progress: 93.41% completed
# Response for Row 86:
# Answer to Question 2: (multiple fragment assembly method, β-carotene biosynthesis pathway), (multiple fragment assembly method, rDNA locus), (β-carotene biosynthesis pathway, production of β-carotene), (production of β-carotene, performance), (rDNA locus, performance), (Yarrowia lipolytica, multiple fragment assembly method), (Yarrowia lipolytica, β-carotene biosynthesis pathway), (Yarrowia lipolytica, rDNA locus), (Yarrowia lipolytica, production of β-carotene), (Yarrowia lipolytica, performance)
# Progress: 94.51% completed
# Response for Row 87:
# Answer to Question 2: (PEI-modified magnetic nanoparticles, lipase), (lipase, vitamin A palmitate), (lipase, vitamin A acetate), (lipase, palmitic acid), (reuse of immobilized lipase, conversion rate), (water removal, conversion rate)
# Progress: 95.60% completed
# Response for Row 88:
# Answer to Question 2: (codon-optimized genes crtB, Yarrowia lipolytica), (codon-optimized genes crtI, Yarrowia lipolytica), (TEF1 promoter, gene expression), (GGS1 genes, isoprenoid biosynthesis), (HMG1 genes, isoprenoid biosynthesis), (POX1 to POX6 deletion, lipid bodies size), (GUT2 deletion, lipid bodies size), (lipid bodies, lycopene storage capacity), (growth-limiting conditions, specific lycopene content), (codon-optimized genes crtB and crtI, lycopene production), (overexpression GGS1 and HMG1, increased lycopene production), (deletion of POX1 to POX6 and GUT2, lipid bodies size increase), (increased lipid body formation, lycopene storage capacity increase)
# Progress: 96.70% completed
# Response for Row 89:
# Answer to Question 2: (gene modification, β-carotene), (gene modification, Yarrowia lipolytica), (β-carotene, subchronic toxicity), (β-carotene, genotoxicity), (Yarrowia lipolytica, β-carotene), (Yarrowia lipolytica, subchronic toxicity), (Yarrowia lipolytica, genotoxicity), (subchronic toxicity, safety profile), (genotoxicity, safety profile)
# Progress: 97.80% completed
# Response for Row 90:
# Answer to Question 2: (genes, lycopene), (genes, Yarrowia lipolytica), (genes, lipid accumulation conditions), (lycopene, Yarrowia lipolytica), (lycopene, lipid accumulation conditions), (Yarrowia lipolytica, lipid accumulation conditions)
# Progress: 98.90% completed
# Response for Row 91:
# Answer to Question 2: (enzyme pathways, lipid mobilization), (enzyme pathways, lipid metabolism), (enzyme pathways, high-value compounds), (lipids, lipid-derived compounds), (lipid stocks, mutant strains), (lipid stocks, recombinant strains), (lipid stocks, substrate combinations), (mutant strains, produced products), (recombinant strains, produced products)
# Progress: 100.00% completed

# %% [markdown]
# **Step 3: Combine entities with similar meanings**

# %%
import pandas as pd
import re
import requests
import numpy as np
import concurrent.futures

##################################################
# 1) READ EXCEL AND EXTRACT ENTITIES
##################################################
df = pd.read_excel(output_file_path, engine="openpyxl")
df["Extracted entities"] = df["Extracted entities"].fillna("")
column_values = df["Extracted entities"].astype(str).tolist()

pattern = r"\(([^,]+), ([^)]+)\)"
entities = []
for value in column_values:
    matches = re.findall(pattern, value)
    for (e1, e2) in matches:
        entities.append(e1)
        entities.append(e2)

# Remove duplicates (preserving the order of first appearance)
entities = list(dict.fromkeys(entities))

##################################################
# 2) GET OLLAMA EMBEDDINGS (PARALLEL)
##################################################
def get_ollama_embedding(text, model):
    """
    Calls Ollama's OpenAI-style /v1/embeddings endpoint.
    Returns a Python list of floats or None on error.
    """
    try:
        r = requests.post(
            "http://localhost:11434/v1/embeddings",
            json={"model": model, "input": text},
            timeout=30
        )
        r.raise_for_status()
        data = r.json()
        # data["data"][0]["embedding"] => the actual embedding vector
        return data["data"][0]["embedding"]
    except Exception as e:
        print(f"Error embedding '{text}': {e}")
        return None

model_name = "qwen2.5:14b"  # Replace with your actual Ollama model name

# --- PARALLELIZE EMBEDDING REQUESTS ---
all_embeddings = []
with concurrent.futures.ThreadPoolExecutor(max_workers=100) as executor:
    # Submit a future for each entity
    future_to_entity = {executor.submit(get_ollama_embedding, ent, model_name): ent for ent in entities}
    
    # Collect results as they complete
    for future in concurrent.futures.as_completed(future_to_entity):
        ent = future_to_entity[future]
        try:
            emb = future.result()
            all_embeddings.append((ent, emb))
        except Exception as e:
            print(f"Error for entity '{ent}': {e}")
            all_embeddings.append((ent, None))

# Re-sort embeddings back to original entity order
emb_dict = dict(all_embeddings)  # { "EntityString": embedding or None }
vectors = []
for ent in entities:
    emb_vec = emb_dict[ent]
    if emb_vec is not None:
        vectors.append(np.array(emb_vec, dtype=np.float32))
    else:
        vectors.append(None)

##################################################
# 3) COSINE SIMILARITY (VECTORIZED IN NUMPY)
##################################################
# We need a consistent dimensionality, so fill None embeddings with zeros
valid_vectors = [v for v in vectors if v is not None]
if not valid_vectors:
    print("No valid embeddings found, cannot proceed.")
    exit()

dim = len(valid_vectors[0])
for i, v in enumerate(vectors):
    if v is None:
        vectors[i] = np.zeros(dim, dtype=np.float32)

# Create a single 2D array: shape (N, D)
matrix = np.stack(vectors)  # shape (N, D)

# Dot product matrix (N x N)
dot_matrix = matrix @ matrix.T
norms = np.linalg.norm(matrix, axis=1, keepdims=True)  # shape (N,1)
denominator = norms @ norms.T                           # shape (N,N)
similarity_matrix = dot_matrix / denominator

threshold = 0.8
N = len(entities)
similar_phrases = {}

# --------------------------------------------------------
# We use np.triu_indices(N, k=1) => all i<j pairs in [0..N-1].
# This covers every unique pair exactly once, no duplication.
# --------------------------------------------------------
upper_indices = np.triu_indices(N, k=1)  # i<j
sim_vals = similarity_matrix[upper_indices]  # 1D array: sim for each pair (i<j)
above_thresh = np.where(sim_vals > threshold)[0]

for idx in above_thresh:
    i = upper_indices[0][idx]  # row index
    j = upper_indices[1][idx]  # col index
    # If sim > threshold, we say entity j is similar to entity i
    similar_phrases[entities[j]] = entities[i]

##################################################
# 4) REPLACE SIMILAR PHRASES IN THE DATAFRAME
##################################################
total_rows = len(df)
for row_idx in range(total_rows):
    if row_idx % 100 == 0 or row_idx == total_rows - 1:
        print(f"Progress: {100.0 * row_idx / total_rows:.1f}%")

    cell_value = str(df.at[row_idx, "Extracted entities"])
    
    # If "Yarrowia" appears in the cell, skip it
    if "Yarrowia" in cell_value:
        continue

    for similar, original in similar_phrases.items():
        # Also skip if "Yarrowia" is in the phrase itself
        if "Yarrowia" in similar:
            continue
        if similar in cell_value:
            cell_value = cell_value.replace(similar, original)

    df.at[row_idx, "Extracted entities"] = cell_value
modified_file_path = 'modified_' + output_file_path
df.to_excel(modified_file_path, index=False, engine="openpyxl")
print("Done. Saved modified file.")
# Out:
# Progress: 0.0%
# Progress: 98.9%
# Done. Saved modified file.

# %% [markdown]
# **Step 4.1: Plot knowledge graph**

# %%
from pyvis.network import Network
import pandas as pd
import re
import networkx as nx

# Load the Excel file
filepath = modified_file_path
df = pd.read_excel(filepath, engine='openpyxl')

# Initialize NetworkX Graph
G = nx.Graph()

# Nodes to exclude
words_to_exclude = []

# Regular expression to match the pattern (entity A, entity B)
pattern = r'\(([^,]+), ([^\)]+)\)'

# Iterate over the DataFrame rows to extract entity pairs and their sources
for _, row in df.iterrows():
    value = row['Extracted entities']
    source = row['Title']  # Extract source for each pair

    matches = re.findall(pattern, value)
    for entity_a, entity_b in matches:
        # Check if any word to exclude is part of the entity names
        if not any(word in entity_a for word in words_to_exclude) and not any(word in entity_b for word in words_to_exclude):
            G.add_node(entity_a, label=entity_a)
            G.add_node(entity_b, label=entity_b)
            G.add_edge(entity_a, entity_b, title=source)

def search_network(graph, keywords, depth=1):
    # Ensure all keywords are lowercase for case-insensitive search
    keyword_list = [kw.lower() for kw in keywords]

    # Helper function to check if a node label contains all keywords
    def contains_all_keywords(label):
        return all(kw in label.lower() for kw in keyword_list)

    # Collect nodes that contain all keywords in their label
    nodes_of_interest = set()
    for node, attr in graph.nodes(data=True):
        if 'label' in attr and contains_all_keywords(attr['label']):
            nodes_of_interest.add(node)

    # Expand search to include neighbors up to the specified depth
    for _ in range(depth):
        neighbors = set()
        for node in nodes_of_interest:
            neighbors.update(nx.neighbors(graph, node))
        nodes_of_interest.update(neighbors)
    
    # Return a subgraph containing only relevant nodes and edges
    return graph.subgraph(nodes_of_interest).copy()

# Perform search with a list of keywords
word_combinations = ["carotene"]  # Replace with your keywords
filtered_graph = search_network(G, word_combinations)

# Extract node names from the filtered graph
node_names = list(filtered_graph.nodes())

# Prepare a simple text summary of node names
node_names_text = ", ".join(node_names)

# Now, `node_names_text` contains a clean, comma-separated list of node names, ready for summarization
print(node_names_text)

# Initialize Pyvis network with the filtered graph
net = Network(height="2160px", width="100%", bgcolor="#222222", font_color="white")
net.from_nx(filtered_graph)

# Continue with setting options and saving the network as before
net.set_options("""
{
  "physics": {
    "barnesHut": {
      "gravitationalConstant": -80000,
      "centralGravity": 0.5,
      "springLength": 75,
      "springConstant": 0.05,
      "damping": 0.09,
      "avoidOverlap": 0.5
    },
    "maxVelocity": 100,
    "minVelocity": 0.1,
    "solver": "barnesHut",
    "timestep": 0.3,
    "stabilization": {
        "enabled": true,
        "iterations": 500,
        "updateInterval": 10,
        "onlyDynamicEdges": false,
        "fit": true
    }
  },
  "nodes": {
    "font": {
      "size": 30,
      "color": "white"
    }
  }
}
""")

# Save and show the network
net.write_html('filtered_entity_' + "_".join(word_combinations) + '_network.html')
# Out:
# increased β-carotene titer, α-carotene, genotyping yeast, carB, overall β-carotene concentration, glucose, optimized fermentation conditions, production capability, β-carotene ketolase, carRP, β-carotene hydroxylases CrtZ, astaxanthin, intermediates' accumulation, β-carotene production, beta-carotene synthesis related genes copy number increase, HMG1, production of β-carotene, zeaxanthin, morphological transition, retinol, enhancing MVA pathway, Y. lipolytica, α-carotene production, HMG-CoA and FPP accumulation, salinity stress, lipids production, mycelium to yeast form conversion, β-carotene accumulation, downregulation of SQS1, glycerol, gene modification, fermentation delay, transcriptional units, subchronic toxicity, subcellular organelles, indigoidine titer yield, alleviating rate-limiting steps, genes crtI, β-carotene hydroxylase from Chondromyces crocatus, glucose consumption, increased β-carotene production, metabolic engineering, beta-carotene, β-carotene biosynthesis pathway, multiple fragment assembly method, fed-batch fermentation, Y. lipolytica XK19, metabolic stress relief, GGS1, fermenter cultivation, yeast, beta-carotene content increase, β-carotene content per cell, β-carotene biosynthetic pathway's metabolic balance, genes crtE, codon-adapted genes, dry cell weight, bioprocess conditions, β-carotene titer, Yarrowia lipolytica, DCW, mevalonate pathway gene expression, lipid overproducer strain, β-carotene concentration, carotenoid-producing strains, species Yarrowia lipolytica, strain, EasyClone, β-carotene biosynthetic genes, gene GGS1, genes crtYB, genes, GGS1/crtE, genotoxicity, homologous recombination, key genes, β-carotene content, metabolic balance, carB and carRP genes, β-cryptoxanthin, genes encoding β-hydroxylase, performance, NAA-dependent NAA-dependent MFE1 degradation, β-carotene extracellular export, precursor supply, crtW, carotene, CRISPR/Cas9, β-carotene hydroxylases, lipophilic properties, β-carotene levels, carotene biosynthetic pathway, mevalonate pathway genes, α-carotene synthase OluLCY, β-carotene-producing strain, rate-limiting steps, phenotypic screen, Yarrowia lipolytica XK2, expression of crtI and crtYB, engineered strain Yli-C, wild type, genetically modified Y. lipolytica strains, beta-carotene production, β-carotene synthesis pathway genes, DO-stat flask culture conditions, FAD1, encapsulation effectiveness, acetic acid, fatty acid synthesis pathway enhancement, heterologous pathway, absence of β-carotene production, ERG13, growth profile, pH effects, β-carotene yield, canthaxanthin, β-carotene titer yield, beta-carotene titer, boosting native precursor supply, Yl-SPT15 mutants, HMG, genes encoding β-ketolase, β-carotene biosynthesis, improved β-carotene production, carotene production, OSH3, fermentation outcomes, flask culture conditions, β-carotene, minimizing intermediate accumulation, YPD culture conditions, industrial production, enzyme tHMGR, beta-carotene production pathway enhancement, ura3Δ strains, OsTIR1, SQS1, substrates, retinal, β-carotene ketolases CrtW, acetic acid concentration, morphology, acetic acid consumption, genome engineering, tHMG1 gene overexpression, β-carotene synthesis, carS, carotenes, platform strain, increased β-carotene accumulation, gene expression

# %% [markdown]
# **Step 4.2 produce summarization report**

# %%
from IPython.display import Markdown
import requests  # Required for API calls

def trim_text(text, max_length):
    if len(text) > max_length:
        return text[:max_length].rsplit(' ', 1)[0] + "..."  # Trim to max_length, avoid cutting words in half
    else:
        return text

# Apply the trimming function to node_names_text
cut_off_chunk_size = 5000
trimmed_node_names_text = trim_text(node_names_text, cut_off_chunk_size)
keyword = ", ".join(word_combinations)

# Construct the prompt with the potentially trimmed node_names_text
prompt = "These are the terms related to " + filepath + keyword + ", categorize them and write a summary report.   " + trimmed_node_names_text

messages = [
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": prompt}
]

try:
    # Use Ollama's OpenAI-compatible API
    response = requests.post(
        'http://localhost:11434/v1/chat/completions',
        json={
            'model': 'qwen2.5:14b',  # Verify with `ollama list`
            'messages': messages,
            'max_tokens': 5000,
            'timeout': 10000  # 10 seconds
        }
    )
    response.raise_for_status()
    response1 = response.json()['choices'][0]['message']['content']
    
except Exception as e:
    print(f"API Error: {e}")
    response1 = "Failed to generate response"

display(Markdown(response1))
# Out:
# ### Summary Report: Terms Related to β-Carotene Production in _Yarrowia lipolytica_
#
# #### Introduction
# This report classifies and summarizes the various terms related to β-carotene production in *Yarrowia lipolytica*. The objective is to provide an organized overview of genetic modifications, metabolic engineering techniques, and bioprocess conditions aimed at enhancing the production of this important carotenoid.
#
# #### Categorization
#
# 1. **Genetic Modifications**
#    - Increased copy number: β-carotene synthesis related genes
#    - Gene modification methods: CRISPR/Cas9, multiple fragment assembly method (MFA), codon-adapted genes, homologous recombination
#    - Genes involved in the pathway:
#      - crtB (carB) and carRP
#      - β-carotene hydroxylases (crtZ, GGS1/crtE)
#      - Upregulated genes: HMG1, crtI, crtYB
#      - Downregulated gene: SQS1
#      - Additional key enzymes/enzymes from heterologous organisms:
#        - β-ketolase CrtW (Chondromyces crocatus)
#        - Hydroxylases
#
# 2. **Bioprocess Conditions**
#    - Fermentation parameters:
#      - Fed-batch fermentation, DO-stat flask culture conditions
#      - Optimization: glucose consumption rate, salinity stress, pH effects, acetic acid concentration and utilization
#      - Cultivation conditions: YPD medium, fermenters
#    - Stress Relief and Metabolic Balance:
#      - Relieving metabolic stress
#      - Alleviating rate-limiting steps
#      - Enhancing precursor supply
#      - NAA-dependent MFE1 degradation
#
# 3. **Metabolic Pathways**
#    - Mevalonate (MVA) pathway: Improved expression, ERG13, HMG-CoA and FPP accumulation
#    - Enhancement of native pathways:
#      - Precursor boosting in mevalonate pathway (tHMG1 gene overexpression)
#      - β-carotene biosynthetic pathway metabolic balance
#      - Homologous enzymes from other organisms (e.g., OluLCY, HMG)
#
# 4. **Product and Analytical Methods**
#    - Product measurement: Increased β-carotene titer, accumulation, extracellular export
#    - Performance metrics:
#      - Dry cell weight (DCW), β-carotene content per cell, biomass productivity
#      - α- and β-carotenes, zeaxanthin, lutein, astaxanthin
#      - Yield: Indigoidine titer yield, subchronic toxicity, genotoxicity tests
#    - Subcellular organelles: ER, mitochondria
#
# 5. **Strain Engineering**
#    - Yarrowia lipolytica strains:
#      - Improved strains (XK19/Yli-C)
#      - Lipid overproducer strain
#      - Genetically modified strains
#    - Gene deletion mutants: Ura3Δ
#
# #### Summary
# The report categorizes the extensive list of terms into key areas focused on enhancing β-carotene production through genetic modification, optimizing fermentation conditions, and improving metabolic pathways in *Yarrowia lipolytica*. Genetic techniques such as CRISPR/Cas9 and MFA have been employed to modify critical genes within the carotenoid biosynthesis pathway. Additionally, metabolic engineering strategies target rate-limiting steps and precursor supply for improving β-carotene synthesis efficiency.
#
# Bioprocess conditions have also seen significant optimization through fed-batch fermentations and DO-stat flask culture methods, with a focus on alleviating metabolic stress to enhance biomass productivity. Strain development has led to the creation of high-performing strains like XK19/Yli-C, enabling higher β-carotene titers with improved precursor supply from the MVA pathway.
#
# Overall, this report reflects the comprehensive approach undertaken in enhancing β-carotene production in *Yarrowia lipolytica*, integrating genetic advancements and bioprocess optimization at both microscale bench experiments and large-scale fermenter applications.
